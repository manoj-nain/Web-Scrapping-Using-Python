# %% [markdown]
# # Scrapping Cricinfo
#
# Check below pages:
#
# https://pydoc.net/python-espncricinfo
#
# https://github.com/dwillis/python-espncricinfo

# %%
pip install python-espncricinfo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install grequests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from espncricinfo.summary import Summary
from espncricinfo.match import Match 
from espncricinfo.series import Series
# Out:
# C:\Users\Manoj\Anaconda3\lib\site-packages\grequests.py:22: MonkeyPatchWarning:
#
# Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.contrib.pyopenssl (C:\\Users\\Manoj\\Anaconda3\\lib\\site-packages\\urllib3\\contrib\\pyopenssl.py)'].
#
# C:\Users\Manoj\Anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning:
#
# libuv only supports millisecond timer resolution; all times less will be set to 1 ms

# %%
from espncricinfo.match import Match
m = Match('1119549')
m.description
# Out:
# 'India tour of Ireland and England, 1st Test: England v India at Birmingham, Aug 1-4, 2018'

# %%
m.status
# Out:
# 'complete'

# %%
print(m.match_class)
print(m.season)
# Out:
# Test
# 2018

# %%
print(m.description)
# Out:
# India tour of Ireland and England, 1st Test: England v India at Birmingham, Aug 1-4, 2018

# %%
print(m.series)
# Out:
# [{'class_id': '1', 'class_name': 'Tests', 'content_id': '12033', 'core_recreation_id': '18097', 'date': 'Aug-Sep 2018', 'end_date': '11 Sep 2018', 'end_date_raw': '2018-09-11', 'final_type_name': 'preliminary matches', 'group_title': '', 'major_trophy': '0', 'match_number': '1', 'match_title': '1st Test', 'match_type_name': None, 'multiformat_pointstable': 'N', 'number_of_hosts': '1', 'number_of_matches': '1', 'number_of_teams': '2', 'object_id': '1119531', 'points': '0', 'primary_series': 'N', 'replayed_date': None, 'schedule_note': '', 'score_module_position': '0', 'season': '2018', 'series_abbreviation': None, 'series_category_id': '1', 'series_category_name': 'competition', 'series_filename': 'IND_IN_ENG', 'series_lead_abandoned': '0', 'series_lead_cancelled': '0', 'series_lead_how_won_name': 'outright', 'series_lead_lost': '0', 'series_lead_result_name': 'led', 'series_lead_team_name': 'England', 'series_lead_total': '5', 'series_lead_type_name': 'series', 'series_lead_won': '1'
# ...

# %%
print(m.officials)
# Out:
# [{'age_days': '56', 'age_years': '50', 'alpha_name': 'ALEEM_DAR', 'batting_hand': 'right-hand batsman', 'bowling_hand': 'right-arm bowler', 'bowling_pacespin': 'spin bowler', 'card_long': 'Aleem Dar', 'card_qualifier': '', 'card_short': 'Aleem Dar', 'dob': '1968-06-06', 'known_as': 'Aleem Dar', 'mobile_name': 'Aleem Dar', 'object_id': '39157', 'player_id': '19103', 'player_type': '2', 'player_type_name': 'umpire', 'popular_name': '', 'portrait_alt_id': '1', 'portrait_object_id': '953883', 'status_id': '3', 'team_abbreviation': 'PAK', 'team_id': '7', 'team_name': 'Pakistan', 'team_short_name': 'Pakistan'}, {'age_days': '244', 'age_years': '42', 'alpha_name': 'GAFFANEY,CB', 'batting_hand': 'right-hand batsman', 'bowling_hand': 'unknown arm', 'bowling_pacespin': 'mixture/unknown', 'card_long': 'CB Gaffaney', 'card_qualifier': '', 'card_short': 'CB Gaffaney', 'dob': '1975-11-30', 'known_as': 'Chris Gaffaney', 'mobile_name': 'Gaffaney', 'object_id': '37097', 'player_id': '9709', 'player_t
# ...

# %%
print(m.current_summary)
print(m.present_datetime_local)
print(m.present_datetime_gmt)
print(m.start_datetime_local)
print(m.start_datetime_gmt)
print(m.cancelled_match)
print(m.rain_rule)
print(m.date)
print(m.continent)
print(m.town_area)
print(m.town_name)
print(m.match_title)
print(m.result)
print(m.ground_id)
# Out:
# None
# 2020-06-09 13:43:00
# 2020-06-09 12:43:00
# 2018-08-01 11:00:00
# 2018-08-01 10:00:00
# False
# None
# 2018-08-01
# Europe
#
# Birmingham
# 1st Test
# England won by 31 runs
# 164

# %%
m.team_1_innings
# Out:
# {'ball_limit': '0',
#  'balls': '538',
#  'batted': '1',
#  'batting_team_id': '1',
#  'bowling_team_id': '6',
#  'bpo': '6',
#  'byes': '9',
#  'event': '1',
#  'event_name': 'all out',
#  'extras': '13',
#  'innings_number': '1',
#  'innings_numth': '1st',
#  'lead': '287',
#  'legbyes': '4',
#  'live_current': '0',
#  'live_current_name': None,
#  'minutes': None,
#  'noballs': '0',
#  'old_penalty_or_bonus': '0',
#  'over_limit': '0.0',
#  'over_limit_run_rate': None,
#  'over_split_limit': '0.0',
#  'overs': '89.4',
#  'overs_docked': '0',
#  'penalties': '0',
#  'penalties_field_end': '0',
#  'penalties_field_start': '0',
#  'run_rate': '3.20',
#  'runs': '287',
#  'target': '0',
#  'wickets': '10',
#  'wides': '0'}

# %%
m.match_winner
# Out:
# 'ENG'

# %% [markdown]
# For player details, pass in the player ID (found in a player's URL - for example, Ajinkya Rahane is '277916'):

# %%
from espncricinfo.player import Player
p = Player('303669')
print(p.name)
p.major_teams
# Out:
# Joe Root
# ['England',
#  'England Lions',
#  'England Under-19s',
#  'Sydney Thunder',
#  'Yorkshire',
#  'Yorkshire 2nd XI',
#  'Yorkshire Academy',
#  'Yorkshire Under-17s']

# %%
p.url
# Out:
# 'http://www.espncricinfo.com/ci/content/player/303669.html'

# %%
p.batting_fielding_averages
# Out:
# {'Tests': {'matches': '92',
#   'innings': '169',
#   'not_out': '12',
#   'runs': '7599',
#   'high_score': '254',
#   'batting_average': '48.40',
#   'balls_faced': '13931',
#   'strike_rate': '54.54',
#   'centuries': '17',
#   'fifties': '48',
#   'fours': '856',
#   'sixes': '21',
#   'catches': '114',
#   'stumpings': '0'},
#  'ODIs': {'matches': '146',
#   'innings': '137',
#   'not_out': '21',
#   'runs': '5922',
#   'high_score': '133*',
#   'batting_average': '51.05',
#   'balls_faced': '6775',
#   'strike_rate': '87.40',
#   'centuries': '16',
#   'fifties': '33',
#   'fours': '478',
#   'sixes': '43',
#   'catches': '74',
#   'stumpings': '0'},
#  'T20Is': {'matches': '32',
#   'innings': '30',
#   'not_out': '5',
#   'runs': '893',
#   'high_score': '90*',
#   'batting_average': '35.72',
#   'balls_faced': '707',
#   'strike_rate': '126.30',
#   'centuries': '0',
#   'fifties': '5',
#   'fours': '92',
#   'sixes': '16',
#   'catches': '18',
#   'stumpings': '0'},
# ...

# %%
p.get_html()
# Out:
# <div class="pnl490M">
# <div class="ciPlayernametxt" style="_width:467px;">
# <div style="margin:0; float:left; padding-bottom:3px;">
# <h1>Joe Root<a alt="Joe Root RSS Feed" href="/rss/content/story/feeds/303669.rss" id="rssIcon" style="padding: 1px 0 0 0;" title="Joseph Edward Root RSS Feed">      </a>
# </h1>
# <h3 class="PlayersSearchLink"><b>England</b></h3>
# </div>
# </div>
# <div style="float:left;display:table-cell; margin-bottom: 10px; _width:472px;">
# <div style="float:left; width:310px; color:#666666; font-size:11px;">
# <p class="ciPlayerinformationtxt"><b>Full name</b>
# <span>Joseph Edward Root</span></p>
# <p class="ciPlayerinformationtxt"><b>Born</b>
# <span>
# December 30, 1990, Sheffield, Yorkshire </span></p>
# <p class="ciPlayerinformationtxt"><b>Current age</b> <span>29 years 162 days</span></p>
# ...

# %%
from espncricinfo.series import Series
s = Series('18018')
s.name
# Out:
# 'India tour of Ireland and England 2018'

# %%
s.years
# Out:
# ['2018']
