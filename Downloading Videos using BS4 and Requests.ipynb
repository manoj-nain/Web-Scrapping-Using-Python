# %% [markdown]
# # Downloading videos using request and Bs4

# %%
import requests
from bs4 import BeautifulSoup
'''
URL of the archive web-page which provides link to
all video lectures. It would have been tiring to
download each video manually.
In this example, we first crawl the webpage to extract
all the links and then download videos.
'''
 
# specify the URL of the archive here
archive_url = "http://www-personal.umich.edu/~csev/books/py4inf/media/"
 
def get_video_links():
    #create response object
    r = requests.get(archive_url)
    #create beautiful-soup object
    soup = BeautifulSoup(r.content,'html5lib')
    #find all links on web-page
    links = soup.findAll('a')
    #filter the link ending with .mp4
    video_links = [archive_url + link['href'] for link in links if link['href'].endswith('mp4')]
 
    return video_links
 
get_video_links()
# Out:
# ['http://www-personal.umich.edu/~csev/books/py4inf/media/PY4INF-13-Webservices-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/PY4INF-13-Webservices-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/PY4INF-13-Webservices-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/PY4INF-13-Webservices-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/PY4INF-13-Webservices-03.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/PY4INF-13-Webservices-03.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-00-Autograder.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-00-Autograder.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-00-Day-One.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-00-Day-One.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-01-Intro.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-01-Intro.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-02-Expressions.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-02-Expressions.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-03-Conditional.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-03-Conditional.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-04-Functions.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-04-Functions.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-05-Iterations.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-05-Iterations.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-06-Strings.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-06-Strings.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-07-Files.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-07-Files.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-08-Lists.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-08-Lists.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-09-Dictionaries.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-09-Dictionaries.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-10-Tuples.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-10-Tuples.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-11-Regex.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-11-Regex.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-02-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-02-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-02-03.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-02-03.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-03-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-03-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-03-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-03-02.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-04-06.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-04-06.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-05-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-05-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-06-07.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-06-07.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-07-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-07-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-08.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-08.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-09.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-09.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-10.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-10.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-13-01.mp4',
#  'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-13-01.mp4']

# %%
def download_video_series(video_links):
 
    for link in video_links:
        '''
        iterate through all links in video_links
        and download them one by one
        '''
 
        #obtain filename by splitting url and getting last string
        file_name = link.split('/')[-1]   
 
        print ("Downloading file:%s"%file_name)
 
        #create response object
        r = requests.get(link, stream = True)
 
        #download started
        with open(file_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size = 1024*1024):
                if chunk:
                    f.write(chunk)
 
        print ("%s downloaded!\n"%file_name)
 
    print ("All videos downloaded!")
    return
 
if __name__ == "__main__":
    #getting all video links
    video_links = get_video_links()
 
    #download all videos
    download_video_series(video_links)
# Out:
# Downloading file:PY4INF-13-Webservices-01.mp4
# PY4INF-13-Webservices-01.mp4 downloaded!
#
# Downloading file:PY4INF-13-Webservices-01.mp4
# PY4INF-13-Webservices-01.mp4 downloaded!
#
# Downloading file:PY4INF-13-Webservices-02.mp4
# PY4INF-13-Webservices-02.mp4 downloaded!
#
# Downloading file:PY4INF-13-Webservices-02.mp4
# PY4INF-13-Webservices-02.mp4 downloaded!
#
# Downloading file:PY4INF-13-Webservices-03.mp4
# PY4INF-13-Webservices-03.mp4 downloaded!
#
# Downloading file:PY4INF-13-Webservices-03.mp4
# PY4INF-13-Webservices-03.mp4 downloaded!
#
# Downloading file:Py4Inf-00-Autograder.mp4
# Py4Inf-00-Autograder.mp4 downloaded!
#
# Downloading file:Py4Inf-00-Autograder.mp4
# Py4Inf-00-Autograder.mp4 downloaded!
#
# Downloading file:Py4Inf-00-Day-One.mp4
# Py4Inf-00-Day-One.mp4 downloaded!
#
# Downloading file:Py4Inf-00-Day-One.mp4
