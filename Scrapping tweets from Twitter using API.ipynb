# %% [markdown]
# #                               Scraping COVID19 Tweets from Twitter using API's
#
#
# > 1. Mounting Google Drive

# %% [markdown]
# In The frirst line of code we will mount Google Drive to Google Colab. This is required to access files stored in google drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# > 2. Creating Properties file to save and access APIKey, SecretAPIkey, Accesstoken and secret access token
#
#
# > To connect to twitter
#
#
# [twitter]
# accesstoken = xxxxxxxxxxxxxxxxxx
#
# accesstokensecret = xxxxxxxxxxxxxxxxx
#
# apikey = xxxxxxxxxxxxxxxxxxxxxx
#
# apisecretkey = xxxxxxxxxxxxxxxxxxxxx
#
# > To connect with google maps to get the location of users
#
# googleapikey = xxxxxxxxxxxxxxxxxxxxx

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/twitter.properties'
# Out:
# '/content/drive/My Drive/Colab Notebooks/twitter.properties'

# %% [markdown]
# 3. Installing and Importing Packages
#
#
#
# *   ConfigParser: Used to read the properties file

# %%
# !pip install ConfigParser
# Out:
# Requirement already satisfied: ConfigParser in /usr/local/lib/python3.6/dist-packages (5.0.0)

# %%
import configparser
config = configparser.RawConfigParser()
config.read(filenames = '/content/drive/My Drive/Colab Notebooks/twitter.properties')
print(config.sections())
# Out:
# ['twitter']

# %% [markdown]
# *   Above we can see [twitter] is the only section in our properties file.
# *   But we can have multiple sections based on our requirements.
#
#
#
# > Install and import Tweepy
#
#
# *   Tweepy is a library used to read tweets.

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2020.4.5.1)

# %%
import os
import tweepy as tw

# %% [markdown]
# > 4. Accessing API's

# %%
accesstoken = config.get('twitter','accesstoken')  #creating 4 varaibles and assigning them basically saying read these 4 keys from file and assign 
accesstokensecret = config.get('twitter','accesstokensecret')
apikey = config.get('twitter','apikey')
apisecretkey = config.get('twitter','apisecretkey')

# %%
auth = tw.OAuthHandler(apikey,apisecretkey) #calling OAuthHandler required for authantication with Twitter
auth.set_access_token(accesstoken,accesstokensecret)

#calling tw.API func. wait_on_rate_limit is required because twitter has set a limit
api = tw.API(auth,wait_on_rate_limit=True)

# %%
search_word = '#coronavirus'
date_since = '2020-05-18'

# %%
#creating a tweepy itemiterator tweets for searching by calling tw.Cursor func, pulling only 1000 records
tweets = tw.Cursor(api.search,q = search_word, lang ='en',since = date_since).items(1000)

# %%
tweets

# %% [markdown]
# # Extracting tweets using Hashtag i.e. search word

# %%
# get geo = where its tweeted from, location = user location etc.
tweet_details = [[tweet.geo,tweet.text,tweet.user.screen_name,tweet.user.location]for tweet in tweets]
tweet_details
# Out:
# [[None,
#   '#Delhi | CM #ArvindKejriwal to address a press conference at 5.30pm today on the #Coronavirus situation.… https://t.co/uRgLvCOoaP',
#   'thefirstindia',
#   'Jaipur, India'],
#  [None,
#   'RT @KJWatersAuthor: #Coronavirus got you down?  Escape with this superb #Timetravel "This series has it all! Romance, intrigue, time travel…',
#   'crystalseries',
#   'book/author info at'],
#  [None,
#   '4/4..... if we take into account the conditionality that will be imposed in the future.\n\n#Europe #EU #solidarity… https://t.co/AvTF1kJi1u',
#   'LaTravelle',
#   'United Kingdom'],
#  [None,
#   'Mit @PavloKlimkin @UkrInFuture in @TheEuropean @TheEuropeanMag\n#koronavirus #coronavirus #covid19pandemic #pandemie… https://t.co/fvgcUwoI6Q',
#   'UmlandAndreas',
#   'Kyiv'],
#  [None,
#   'RT @HSELive: As we enter Phase One of the #COVID19 Roadmap, we are still asking people to stay at home to help slow the spread of #coronavi…',
#   'artsandhealthie',
#   'Ireland'],
#  [None,
#   'RT @Lolamaybenot: Due to #COVID19 / #Coronavirus ill be sending the first 500 people to like &amp; retweet this $300 -$1500 through CashApp, Ap…',
#   'zagayo',
#   ''],
#  [None,
#   '#obzevaxion20 for day back in seven weeks. They say there is nothing as empty as an empty stadium. I promise you th… https://t.co/75tgMVFxjv',
#   'The_Obzeva',
#   'Aforika  ...'],
#  [None,
#   'The prime minister said in a statement to a #British newspaper that the virus could not be vaccinated against… https://t.co/4vL9ebkFeq',
#   'ConceptTVNews',
#   'World'],
#  [None,
#   'RT @MillerCrime: @Jankowski60 He works in a hobby store\n\nThe point is to crowd around and open packs of cards, sit close together playing g…',
#   'AutisticPov',
#   ''],
#  [None,
#   "RT @khoasa: #day44oflockdown #MyPostLockdownSA #SteenhuisenVSMboweni #coronavirus \nFrom the 80s back i know y'all are our ancestors and y'a…",
#   'InnieLycot',
#   'Rustenburg, South Africa'],
#  [None,
#   "somebody who was positive for #COVID19 intended mother's day church services and exposed 180 other people in Califo… https://t.co/yMMCB4c6Hq",
#   'robert_weiter',
#   'United States '],
#  [None,
#   'RT @VOG_2020: #MilesGuo Talking about the #coronavirus #CCPVirus https://t.co/KN459dd4rR',
#   'c8bcMq2ie7Dj0TF',
#   ''],
#  [None,
#   'RT @abc7newsbayarea: "PLEASE OPEN UP MY NAIL SALON!" Small business owners and their families rallied in Livermore on Saturday pleading off…',
#   'docboogie',
#   'Texas or Montana '],
#  [None,
#   'RT @_Jagadguru: #ServeNeedyInLockdown \nDistributed food and  daily essentials  to the needy in #Ratnagiri. This #Lockdownextention causing…',
#   'NitaShinde14',
#   ''],
#  [None,
#   'RT @MillerCrime: @Jankowski60 He works in a hobby store\n\nThe point is to crowd around and open packs of cards, sit close together playing g…',
#   'MillerCrime',
#   ''],
#  [None,
#   'RT @KRG_DFR: Thank you to our national heroes, who work tirelessly every day to keep us safe. #Coronavirus\n\nسـوپاس بۆ پاڵەوانەکانی نیشـتیما…',
#   'KRG_DFR',
#   'Kurdistan Region-Erbil'],
#  [None,
#   'RT @beisgovuk: .@UniofOxford and @AstraZeneca have signed a global licensing agreement for the manufacturing of their potential #coronaviru…',
#   'Bb4Global',
#   ''],
#  [None,
#   'RT @htdelhi: #CoronavirusPandemic | Delhi CM Arvind Kejriwal to address a press conference at 5.30pm today on the #coronavirus situation.…',
#   'johnsonouseph4j',
#   'Persian Gulf'],
#  [None,
#   "RT @JerryHicksUnite: So, how far up your own arse can you get?I\n\nThis far - Person drive's 1.5 hrs to a beach with her family. Then complai…",
#   'kizzymay58',
#   'Merseyside.'],
#  [None,
#   'RT @scvotweet: We’re asking staff &amp; volunteers from charities, social enterprises, community groups &amp; voluntary organisations to share thei…',
#   'SocEntEdinburgh',
#   'Edinburgh'],
#  [None,
#   'Players of @SuperRugbyNZ will begin their “second pre-season” today as they return to training following health and… https://t.co/Ivv16jK5HG',
#   'alkassdigital',
#   'Doha, Qatar'],
#  [None,
#   'RT @ahmedabadmirror: Gujarat’s largest #Covid19 hospital urgently seeks full-fledged ventilators from Centre\n\n#coronavirus #coronavirusinin…',
#   'Hajindersingh2',
#   'Hindostaan '],
#  [None,
#   'Definitely worth checking out tomorrow’s @resfoundation and @Strath_FAI event on the economic impact of… https://t.co/KENTWFx3MU',
#   'JamesSmithRF',
#   'London, England'],
#  [None,
#   'Does anyone else feel like this? 🌿💚\n\n#Veganism #MondayMotivation #Quote #Coronavirus #Covid19 #SelfIsolation… https://t.co/gjzmfFFk9t',
#   'naturesroot',
#   'London'],
#  [None,
#   'Helping helpers: We’re supporting international &amp; local aid organizations in Germany 🇩🇪 such as the @roteskreuz_de… https://t.co/8MjLnh26w3',
#   'AmazonNewsEU',
#   'Luxembourg'],
#  [None,
#   'RT @JamesMelville: Easing social distancing and lockdown has to happen sooner rather than later to avoid even more economic pain. But witho…',
#   'Vdweller',
#   'Southampton'],
#  [None,
#   '@Jankowski60 He works in a hobby store\n\nThe point is to crowd around and open packs of cards, sit close together pl… https://t.co/ZMLtKRn0T7',
#   'MillerCrime',
#   ''],
#  [None,
#   'RT @thekjgeorge: Visited #ContainmentZone along with leaders and concerned dept’ officials. Instructed officials to keep the area well sani…',
#   'AtifSye45044833',
#   ''],
#  [None,
#   "BBC News - #Coronavirus : Who is behind Glasgow's #Covid street art?\nhttps://t.co/Mx9vpwuY57",
#   'mrsverypicky',
#   'Glasgow environs.'],
#  [None,
#   '🌟 #Anosmia 🌟\n"UK #coronavirus tests advised for people who lose #taste or #smell"\nThey are "being advised to get te… https://t.co/EAaYgy9lHw',
#   'OT_Expert',
#   '💫 Everywhere'],
#  [None,
#   "RT @MOFA_Taiwan: Minister Wu boils the need for #Taiwan's @WHO &amp; #WHA73 participation down to 1 concept: fairness. Watch his interview with…",
#   'ItsJennyChen',
#   'Kingston, Ontario'],
#  [None,
#   'RT @Maha_MEDD: A map prepared by CSIR-NEERI showing #COVIDー19 cases in India. (18th May 2020)\n\n#IndiaFightsCorona #coronavirus #IndiaFights…',
#   'rakeshchauan123',
#   ''],
#  [None,
#   'RT @TelegraphTech: ICYMI: #Uber has abandoned its robotic bikes and scooters project.\n\nThe #coronavirus hit ride-hailing company jettisoned…',
#   'fleming77',
#   'Cambridgeshire England'],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   '_scarface_x',
#   '👨🏾\u200d💻'],
#  [None,
#   'The coronavirus has left many countries with serious economic challenges. Some countries may default on their debts… https://t.co/Rh84hrSZ4R',
#   'NeverlankC',
#   'Harare, Zimbabwe'],
#  [None,
#   'RT @RepChrisSmith: Global Magnitsky sanctions should be imposed on those Chinese government officials who lied and suppressed the truth abo…',
#   'fktws',
#   ''],
#  [None,
#   'RT @theautismdad: How much longer can you continue living under the #COVID19 restrictions?\nPlease Retweet for a larger sample \n\n#coronaviru…',
#   'MeQtipp',
#   'behind every blade of grass US'],
#  [None,
#   'RT @KadiwarKarim: It’s an shameful not to received any update from government. #AtmaNirbharBharatAbhiyan #atmanirbharbharat #coronavirus #C…',
#   'fgyjhjhk',
#   ''],
#  [None,
#   'While Phase One of the easing of #Covid19 restrictions begins today, many restrictions remain, and people are still… https://t.co/8vaIzPauUT',
#   'rtenews',
#   'Ireland'],
#  [None,
#   'RT @kelly2277: 🤔@realDonaldTrump’s personal valet has #coronavirus. The question is, if Trump has been exposed and is shedding virus, can @…',
#   'Orianerose',
#   ''],
#  [None,
#   'RT @HongKongFP: JUST IN: Taiwan postpones request for WHO observer status so members can focus on Covid-19 battle \n\nhttps://t.co/sNSQj065mm…',
#   'smaplee1',
#   ''],
#  [None,
#   'RT @HowardArcherUK: #BOE has long been against negative interest rates but chief economist &amp; #MPC member #Haldane comments indicate bank is…',
#   'annacoull',
#   'Hampshire/UK'],
#  [None,
#   'RT @MalcolmAlkalee: Knowledge is the key to beat #CoronaVirus globally and together we can do it.\n\nPREVENT THE SPREAD OF #COVIDー19:  \n-Wear…',
#   'mahmoud_rilwan',
#   'SOMEWHERE SAFE..'],
#  [None,
#   'RT @tv9gujarati: Migrants gather in Pipodara GIDC area, demanding to send them to native . #Gujarat #surat #coronavirus #lockdown https://t…',
#   'BijendrINC',
#   'Mundka, New Delhi'],
#  [None,
#   'RT @SukiZhou3: Essential products for Commercial resumption of production, Students back to school and business travel  #Thermometer #virus…',
#   'CyberSecurityN8',
#   ''],
#  [None,
#   "RT @MOFA_Taiwan: Minister Wu boils the need for #Taiwan's @WHO &amp; #WHA73 participation down to 1 concept: fairness. Watch his interview with…",
#   'rrose32866857',
#   '横須賀米軍基地内'],
#  [None,
#   'RT @DrDenaGrayson: 🔥Like me, ousted @BARDA head—Dr. Rick Bright—warned IN JANUARY about the #coronavirus: “I knew that all of the signs for…',
#   'teestark',
#   ''],
#  [None,
#   'Thank you to our national heroes, who work tirelessly every day to keep us safe. #Coronavirus\n\nسـوپاس بۆ پاڵەوانەکا… https://t.co/lq4KyeDlv7',
#   'KRG_DFR',
#   'Kurdistan Region-Erbil'],
#  [None,
#   "RT @TheDemCoalition: Dr. Rick Bright says he's trained his entire life to recognize outbreaks and viruses. But when he sounded the alarm ab…",
#   'kristenpmurphy',
#   ''],
#  [None,
#   'RT @g_gosden: Lies, Boris lies, Hancock lies, Gove lies, #torybrexit lies #COVID19 #coronavirus catastrophe https://t.co/oIlQT8ei2D',
#   'goldie_stephen',
#   ''],
#  [None,
#   'RT @theautismdad: How much longer can you continue living under the #COVID19 restrictions?\nPlease Retweet for a larger sample \n\n#coronaviru…',
#   'Metalworks4',
#   ''],
#  [None,
#   'Episode 142: Covid-19: The New Risk and Compliance Framework - Corruption, Crime &amp; Compliance… https://t.co/iMBnABw1N1',
#   'mikevolkov20',
#   'Del Mar, CA; Washington, D.C. '],
#  [None,
#   '@Brexit If not then the price of independence will be extremely high. British citizens will quickly notice this in… https://t.co/iUfrygroS2',
#   'HeineGiessen',
#   'European Union: Frankfurt/Main'],
#  [None,
#   'With #Rouhani forcing the Iranian nation to dive into numerous #CoronaVirus dangers, the people who do manage to re… https://t.co/mFzKOCgrww',
#   '4FreedominIran',
#   ''],
#  [None,
#   'RT @g_gosden: Lies, Boris lies, Hancock lies, Gove lies, #torybrexit lies #COVID19 #coronavirus catastrophe https://t.co/oIlQT8ei2D',
#   'SimonHeppolette',
#   'Peak District, England'],
#  [None,
#   'Who do you want to be during #COVID19 ? \n\nYour way be being in these times will define your success after this… https://t.co/8pioPYX1Qs',
#   'chrrysallis',
#   'Mumbai, India'],
#  [None,
#   'As #coronavirus shocks the energy sector and economy, is now the time for a new energy order?  The crisis offers an… https://t.co/imiX0rxhQD',
#   'EThomasJones',
#   'South Dublin, Ireland'],
#  [None,
#   'RT @RVAwonk: Last month, a digital technology company that is working for Trump’s campaign and created his campaign app (and specializes in…',
#   'Gloria_rocha',
#   ''],
#  [None,
#   "#Sindh's death toll reached 280 on Monday after the province lost three more people to #coronavirus.\n#COVID19… https://t.co/BekbkcON2S",
#   'brecordernews',
#   'Karachi-Pakistan'],
#  [None,
#   'RT @tv9gujarati: Hair Saloon and Beauty Parlours will not be allowed to open in any zone . #Gujarat #lockdown #coronavirus https://t.co/QeE…',
#   'ankur_kaneria',
#   'Ahmedabad'],
#  [None,
#   'RT @MagdaSzubanski: If bingeing Kath &amp; Kim is helping u get thru #Covid_19 wld be great if you thought about how the arts sector (that made…',
#   'KimHMcGrath',
#   'Melbourne, Australia'],
#  [None,
#   'RT @i_theindian: After food delivery platform #Zomato laid-off 520 employees, now #Swiggy strikes off 1,100 employees from their pay-roll.…',
#   'Kalim40263572',
#   ''],
#  [None,
#   'RT @theautismdad: How much longer can you continue living under the #COVID19 restrictions?\nPlease Retweet for a larger sample \n\n#coronaviru…',
#   'LinerRats',
#   ''],
#  [None,
#   'RT @SukiZhou3: Essential products for Commercial resumption of production, Students back to school and business travel  #Thermometer #virus…',
#   'sectest9',
#   'Hyderabad, India'],
#  [None,
#   'RT @RepChrisSmith: Global Magnitsky sanctions should be imposed on those Chinese government officials who lied and suppressed the truth abo…',
#   'FuckCCPandPRC',
#   'Hong Kong'],
#  [None,
#   'RT @DeccanChronicle: #Swiggy to lay off 1,100 employees, or nearly 14% of its workforce, to cut costs, as a weeks-long nationwide #lockdown…',
#   'd33p_crj',
#   ''],
#  [None,
#   'RT @drastichs: Day-to-day review #Slovakia #Slovensko \n\nof Covid-19 progress\n\nhttps://t.co/PyUu9C4ggC #coronavirus #nCoV #nCoV2019 #2019nCo…',
#   'drastichs',
#   'Slovakia'],
#  [None,
#   'RT @AfEconHis: New on AEHN Blog: Editors\' summary of The Journal of African History\'s #COVID_19 #openaccess Special Issue on "Epidemics &amp; P…',
#   'HistoryRegions',
#   ''],
#  [None,
#   'RT @Lolamaybenot: Due to #COVID19 / #Coronavirus ill be sending the first 500 people to like &amp; retweet this $300 -$1500 through CashApp, Ap…',
#   'Lolamaybenot',
#   'California, USA'],
#  [None,
#   'RT @richardaucock: Reminder, London commuters avoiding public transport by driving to work: the Congestion Charge and ULEZ resume from TODA…',
#   'aohereng',
#   'England, United Kingdom'],
#  [None,
#   'RT @mayorcantrell: #MaskUpNOLA: Our people are what make #NewOrleans special. ❤️#SaveALife 😷 Wearing your face covering in public goes a lo…',
#   'NOLABlackMBA',
#   'New Orleans, LA'],
#  [None,
#   'Essential products for Commercial resumption of production, Students back to school and business travel… https://t.co/ZjnXSfRUqx',
#   'SukiZhou3',
#   'Guangdong'],
#  [None,
#   "RT @DEPTH_LSHTM: Today's #mondaymotivation is this @bmj_latest article arguing that the views of patients &amp; the public should be included i…",
#   'DrAyanaJordan',
#   'New Haven, CT'],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   'alli_huncle',
#   'Nigeria.'],
#  [None,
#   'RT @TomthunkitsMind: IS AMERICA READY FOR AN ESTIMATED 3.2 MILLION DEATHS\nFROM THE #CORONAVIRUS ALONG WITH THE VIOLENCE AND CHAOS TO FOLLOW…',
#   'nice_centurion',
#   '🌍Rom, Latium🌞'],
#  [None,
#   'RT @RVAwonk: CloudCommerce, a company whose largest shareholder is Brad Parscale, received nearly $800,000 from the federal #coronavirus re…',
#   'Gloria_rocha',
#   ''],
#  [None,
#   'RT @Taheri_Movement: More than 50  #HumanRights activists have called on Iranian authorities to release prisoner of conscience #GolrokhIrae…',
#   'nahayattt',
#   ''],
#  [None,
#   'RT @cryborg: Perhaps Melania will wear her\n”I don’t really care about the #coronavirus. Do you?” coat. 🤔\n\nThat’s sure to be a big hit with…',
#   'StevenMarkCase1',
#   ''],
#  [None,
#   'Sound advice. 👏👏👏 #StayHome #StaySafe #coronavirus #covid19 https://t.co/zPwcgVDwsR',
#   'swedishbriefs',
#   'London, Kent & Göteborg'],
#  [None,
#   'RT @scotgov: If you’re showing symptoms of #coronavirus – even if they’re mild – here’s what you need to do to keep yourself and others saf…',
#   'WMTYScot',
#   'Scotland, United Kingdom'],
#  [None,
#   '#indtoday: Delhi CM @ArvindKejriwal to address a press conference at 5.30pm today on the #coronavirus situation https://t.co/6P3sn2FgFF',
#   'ind2day',
#   'Hyderabad, india'],
#  [None,
#   'RT @TomthunkitsMind: WATCH THIS:\n\nEmotional Karl-Anthony Towns reveals mother is diagnosed with #Coronavirus is in a coma on a ventilator.…',
#   'nice_centurion',
#   '🌍Rom, Latium🌞'],
#  [None,
#   'A huge thank you to @TNLComFund for allowing our Rapid Reaction @VETERANSCHARITY support for UK Veterans to continu… https://t.co/tsaCbNBTJc',
#   'VCTrustee',
#   'London, England'],
#  [None,
#   'RT @JamesMelville: Easing social distancing and lockdown has to happen sooner rather than later to avoid even more economic pain. But witho…',
#   'souf2norf',
#   'N.E Cumbria'],
#  [None,
#   'RT @_Jagadguru: Jagadguru Narendracharya Maharaj Sansthan has handed over an amount of Rs.52 lakhs today towards #COVID19, #PMCARES  Fund.T…',
#   'NitaShinde14',
#   ''],
#  [None,
#   '“Life is a coin you can spend it any way you wish, but you only spend it once.”#mondaythoughts #USA #UK #India… https://t.co/nFf3WZVlK1',
#   'xyzjyotishcentr',
#   ''],
#  [None,
#   "RT @Balaji_Wafers: You won't stop at one, it's so good! 👌🏻\n\n#balajiwafers #WafersZyaadaFlavourWahWah  #sogood #snacks #wafers #nachos #coro…",
#   'Nitesh69595876',
#   'Jhansi, India'],
#  [None,
#   'RT @thekjgeorge: Visited #ContainmentZone along with leaders and concerned dept’ officials. Instructed officials to keep the area well sani…',
#   'AtifSye45044833',
#   ''],
#  [None,
#   'RT @Lolamaybenot: Due to #COVID19 / #Coronavirus ill be sending the first 500 people to like &amp; retweet this $300 -$1500 through CashApp, Ap…',
#   'SbuZ_ice',
#   ''],
#  [None,
#   '#Qanon #Coronavirus #DemocratsHateAmerica \n\nDaily reminder https://t.co/jEQEE3mJ8s',
#   'paint_texas',
#   'texas'],
#  [None,
#   'RT @DrDenaGrayson: 🔥Like me, ousted @BARDA head—Dr. Rick Bright—warned IN JANUARY about the #coronavirus: “I knew that all of the signs for…',
#   'laura07685518',
#   ''],
#  [None,
#   'RT @NewsLineIFE: #BreakingNews Its Game Over for China? Pompeo said #China allowed people to travel outside despite knowing the risk of #co…',
#   'RishiSharma9415',
#   'New Delhi, India'],
#  [None,
#   'RT @ManMundra: India should now release daily data on #Coronavirus in detailed form, instead of just one set of numbers. \n\nInfected: Age gr…',
#   'ARYAKRANTI',
#   ''],
#  [None,
#   'How do you advise patients observing Ramadan during the #COVID19 pandemic?\n\nPublished today:… https://t.co/OG15HWgu5O',
#   'BJGPOpen',
#   'London, England'],
#  [None,
#   'RT @RepChrisSmith: Global Magnitsky sanctions should be imposed on those Chinese government officials who lied and suppressed the truth abo…',
#   'ThankYouWorld3',
#   ''],
#  [None,
#   'RT @TomthunkitsMind: 1 OF THE 3 #CORONAVIRUS BOMBSHELLS IN MY BOOK HAS JUST BEEN PROVEN TRUE:\nScientists from China have identified two str…',
#   'nice_centurion',
#   '🌍Rom, Latium🌞'],
#  [None,
#   "#Coronavirus latest news: UK 'missing 70,000 cases due to outdated symptoms' list  https://t.co/6A3d2EJFUI via @Telegraph",
#   'McnabbTeddy',
#   ''],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'jojo_3339',
#   ''],
#  [None,
#   'RT @FSDKe: With children at home due to #coronavirus, for some Kenyan families its a reprieve from domestic labour and also a burden on the…',
#   'Covid_Africa',
#   ''],
#  [None,
#   'RT @gergerlioglueng: Gökhan Açıkkollu died of #torture. He was summarily executed. They want to  bury him in a graveyard dubbed the cemeter…',
#   'ataytx',
#   'Dallas, TX'],
#  [None,
#   'RT @zeusFanHouse: #Trump Never Pushed A #Mandatory #COVID19 Vaccine\n\n#Coronavirus #vaccine will be completely #voluntary despite #MSM talki…',
#   'Lee37279995',
#   ''],
#  [None,
#   'RT @FaceTheNation: “I disagree with that assessment on the diagnostic test,” @ScottGottliebMD says after White House Trade Adviser criticiz…',
#   'Dpapa35',
#   'Columbia, TN'],
#  [None,
#   'RT @AdiviSesh: Reading this amazing article from the @guardian about the amazing @shailajateacher from Kerala. Loved how she is saving live…',
#   'Nandagopalan16',
#   ''],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'MacTheDep',
#   'rjmcbroom1964@gmail.com'],
#  [None,
#   '#EU #Vaccines #Coronavirus\n\n#Leaders of #Italy, #France, #Germany,\n#Norway, together with the #EC &amp; #Council,\ncalle… https://t.co/Z4MVa3SOWK',
#   'Carverlon',
#   'Silicon Valley and London.'],
#  [None,
#   'RT @IshitaBhatiaTOI: BREAKING: Three new cases test positive in Meerut; taly reaches 331 (incl one from Kanpur)\n#Meerut #Coronavirus',
#   'WorldJat',
#   'Meerut, India'],
#  [None,
#   '#Coronavirus in charts: are virtual conferences here to stay?\n \nhttps://t.co/syUT2ign5X',
#   'Nightingal_news',
#   'Zurich'],
#  [None,
#   'RT @PriveDoc: -Have breaks from social media and mute things which are triggering⠀\nAnd you how do you deal with anxiety? #onlinedoctors #st…',
#   'PriveDoc_Help',
#   'Lagos, Nigeria'],
#  [None,
#   'RT @SkyNews: Former International Trade Secretary Liam Fox says China is not being open enough about the origins and spread of #coronavirus…',
#   'Jennife49761282',
#   'Carthage'],
#  [None,
#   'RT @PermSecScot: .@jasonleitch kicks off #MentalHealthAwarenessWeek with tips on looking after our mental &amp; physical wellbeing during #coro…',
#   'helenajbee',
#   'Scotland, United Kingdom'],
#  [None,
#   'RT @IshitaBhatiaTOI: BREAKING: Three new cases test positive in Meerut; taly reaches 331 (incl one from Kanpur)\n#Meerut #Coronavirus',
#   'ShivaBhar',
#   'Meerut, New Delhi. INDIA'],
#  [None,
#   "RT @TheDemCoalition: Dr. Rick Bright says he's trained his entire life to recognize outbreaks and viruses. But when he sounded the alarm ab…",
#   'Dr_J67',
#   'Pennsylvania, USA'],
#  [None,
#   'RT @VOG_2020: #MilesGuo Talking about the #coronavirus #CCPVirus https://t.co/KN459dd4rR',
#   'vwCqqd8SXqvQYvH',
#   ''],
#  [None,
#   'RT @basherkella: #BDCovid19 update: 18/05/2020 Monday \n\nNew cases: 1602  \nNew deaths: 21 \n\nTotal cases: 23870 \nTotal deaths: 349 \n\nSource:…',
#   'shahinali102',
#   'Dhaka,Bangladesh'],
#  [None,
#   'From today, loss of smell or taste has been added to #coronavirus symptoms to watch out for as conditions to self-i… https://t.co/FdJ97GvGtm',
#   'lutoncouncil',
#   'Luton, Bedfordshire'],
#  [None,
#   "RT @Join_ZOE: Loss of taste and smell (#anosmia) 👃 due to #COVID19 (as reported in our @NatureMedicine paper) has now been added to the UK'…",
#   'AgnesAyton',
#   'Oxford, England'],
#  [None,
#   'RT @HMRCgovuk: Are you a business with fewer than 250 employees? Did you know that the cost of providing 2 weeks of #coronavirus related St…',
#   'TaxLocal_CM21',
#   'Herts/ Essex Borders'],
#  [None,
#   "RT @TheDemCoalition: Dr. Rick Bright says he's trained his entire life to recognize outbreaks and viruses. But when he sounded the alarm ab…",
#   'GlassRiverJewel',
#   'Maryland'],
#  [None,
#   'RT @barnardos: Our report with @actnforchildren, @childrensociety, @ncbtweets and @NSPCC  urges the government to help local authorities in…',
#   'ray_4_peace',
#   'Leicester'],
#  [None,
#   'RT @drastichs: 1495 confirmed cases(+1)\n143433 tests done(+971)\nDay-to-day growth ratio 1.0007(+0.07%)\nMortality 28 unchanged\nOn May 18 202…',
#   'drastichs',
#   'Slovakia'],
#  [None,
#   'RT @FrankLuntz: You don’t ever hear the term “cytokine storm” in mainstream #coronavirus coverage, but it’s the main reason why COVID-19 is…',
#   'senatorjen',
#   'Atlanta, GA'],
#  [None,
#   'RT @footballitalia: Former #Sassuolo defender Paolo Cannavaro has claimed ‘football is religion’ in Italy and must resume: “It should be pr…',
#   'victorn96567639',
#   ''],
#  [None,
#   "RT @CABinSwale: We're still #heretohelp, and so are others in the #Swale community. Find out more about the support you can receive during…",
#   'SFMRadio',
#   'Sittingbourne'],
#  [None,
#   'RT @Saudi_Gazette: Out of the 2,736 new #coronavirus cases in #SaudiArabia, 557 were confirmed in Makkah, 488 in Riyadh and 392 in Madinah.…',
#   'salmanrushoo',
#   'Mirpur, Dhaka'],
#  [None,
#   '‘Immune to evidence’: Expert explains how dangerous #coronavirus #conspiracies spread https://t.co/iWnfafd0d3',
#   'SemGeek',
#   'Philadelphia, PA'],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'donnasm04063651',
#   'New York'],
#  [None,
#   'RT @PDChina: #Latest on #coronavirus outbreak in #Iran, according to the health ministry: \n- 122,492 cumulative cases, an increase of 2,294…',
#   'yogagirl2021',
#   'planet earth'],
#  [None,
#   '1495 confirmed cases(+1)\n143433 tests done(+971)\nDay-to-day growth ratio 1.0007(+0.07%)\nMortality 28 unchanged\nOn M… https://t.co/5btZVXAg43',
#   'drastichs',
#   'Slovakia'],
#  [None,
#   'RT @HW_Sutton: 1 more day until our poll closes!\n\n📣Tell us your views &amp; help us make sure that everyone continues to receive safe and quali…',
#   'DavidAngryBird',
#   'Sutton, London'],
#  [None,
#   "RT @AshramBlr: Early data suggests~ 'Older people are twice as likely to have serious illness from the novel #coronavirus' according to the…",
#   'DhaiyaParas',
#   'Hyderabad, India'],
#  [None,
#   'RT @theautismdad: How much longer can you continue living under the #COVID19 restrictions?\nPlease Retweet for a larger sample \n\n#coronaviru…',
#   'EmilyHitch1',
#   'United States'],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'noseyer',
#   ''],
#  [None,
#   'RT @EIT_Food: "We need to move to a more circular economy, which would try to build sustainability ♻️ principles into the system", says Pro…',
#   'DamianMaye',
#   'Uni of Gloucestershire'],
#  [None,
#   'RT @JamesMelville: Easing social distancing and lockdown has to happen sooner rather than later to avoid even more economic pain. But witho…',
#   'AllanGPaterson',
#   'Wrexham'],
#  [None,
#   'RT @AJEnglish: US President Trump calls his predecessor Barack Obama “grossly incompetent” after he criticised the administration’s respons…',
#   'khanztuba',
#   'Asif Nagar North, Hyderabad'],
#  [None,
#   'RT @footballitalia: Former #Sassuolo defender Paolo Cannavaro has claimed ‘football is religion’ in Italy and must resume: “It should be pr…',
#   '_LeKido_',
#   ''],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   'AbdulhadiIbrahe',
#   'Katsina Nigeria'],
#  [None,
#   'RT @zeusFanHouse: Nice Try: Governor #Cuomo Says “Nobody Should Be #Prosecuted” for Sticking Sick #Coronavirus Patients into New York Nursi…',
#   'realJediMan1',
#   'DeBary, FL'],
#  [None,
#   'RT @LordProvostGCC: At the start of #MentalHealthAwarenessWeek, it is important to remember, and particularly during this #Coronavirus pand…',
#   'zaaramariia',
#   'Glasgow, Scotland'],
#  [None,
#   "RT @Utsava4: @realDonaldTrump @Boblobblaw88 We said that the #coronavirus will be yesterday's news soon. Now we have the cure, Fauci and Ga…",
#   'Pinklady937',
#   'Kentucky, USA'],
#  [None,
#   '#IBC Show in Amsterdam, Originally Set for Mid-September, Canceled for 2020 Due to #Coronavirus… https://t.co/Lp1GRpz69e',
#   'Current_Knewz',
#   '√α. в૯α૮ђ, √¡૨g¡ท¡α'],
#  [None,
#   'RT @ndtv: Biggest single-day jump of 5,242 #coronavirus cases in India, total cases now 96,169 https://t.co/pRwxtsHSBv',
#   'InFNsanity',
#   'Michigan, USA'],
#  [None,
#   'RT @SkyNews: BREAKING: The Deputy Chief Medical Officer has announced loss of taste and smell is to be added to the official list of COVID-…',
#   'rechiemole',
#   'london england'],
#  [None,
#   "RT @TheDemCoalition: Dr. Rick Bright says he's trained his entire life to recognize outbreaks and viruses. But when he sounded the alarm ab…",
#   'DMBincredible',
#   'Michigan, USA'],
#  [None,
#   'RT @g_gosden: Lies, Boris lies, Hancock lies, Gove lies, #torybrexit lies #COVID19 #coronavirus catastrophe https://t.co/oIlQT8ei2D',
#   'GrandadofOscar',
#   'London, England'],
#  [None,
#   'RT @abc730: The ADF has told 7.30 participation in the trial is entirely voluntary and that there is no pressure coming from Defence, comma…',
#   'fehowarth',
#   'Central Coast NSW'],
#  [None,
#   'RT @ScottAnthonyUSA: Anthony Fauci: The other thing that’s a concern but we will be able to get around, is the vaccine enhancing #COVID / #…',
#   'SimplySara22',
#   'Heaven-bound'],
#  [None,
#   '‘Outraged’ Belgian medics turn their backs in protest at PM @Sophie_Wilmes   handling of #coronavirus pandemic… https://t.co/CG8e7K0oFq',
#   'pash22',
#   'United Kingdom'],
#  [None,
#   'RT @SkyNews: The daughter of a man who died with suspected #coronavirus has told Sky News she wants to know who signed off on a government…',
#   'FalexanderFiona',
#   ''],
#  [None,
#   'Worshippers having their temperature checked at the entrance of the Umayyad mosque in Damascus\n@AFPphoto by Louai B… https://t.co/JD1xUpvgDt',
#   'AFP_Beirut',
#   'Beirut'],
#  [None,
#   'RT @MaryMurrayNBC: #coronavirus is not a hoax.  Mortality rates could be 60% higher than reported. https://t.co/FTUQIRPD1O',
#   'jo3_f',
#   'East Los Angeles, CA'],
#  [None,
#   'RT @TRF_Climate: #India has begun evacuating thousands of villagers &amp; halted port operations ahead of #CycloneAmphan, expected to hit its e…',
#   'meganrowling',
#   'Barcelona, Spain'],
#  [None,
#   'RT @NewsMobileIndia: Lockdown 4.0: States can’t dilute guidelines; can only make them stricter, says MHA      \n\n#Lockdown4 #Coronavirus #CO…',
#   'raghvendra_rao',
#   'New Delhi, India'],
#  [None,
#   'Razer is deploying free mask merchandising machines in singapore https://t.co/DqWIsI4dlf\n\n#freemask #mask #razer #covid19 #coronavirus',
#   'Technol33192645',
#   'New York'],
#  [None,
#   'RT @SkyNews: BREAKING: The Deputy Chief Medical Officer has announced loss of taste and smell is to be added to the official list of COVID-…',
#   'JoshieYoshie23',
#   'England, United Kingdom'],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'Ryan35331497',
#   ''],
#  [None,
#   'RT @indiatvnews: Lockdown 4.0: Restrictions under Section 144 extended in Chhattisgarh for 3 Months | via @IndiaTVNews #Lockdown4 #Coronavi…',
#   'PrietyKumari',
#   ''],
#  [None,
#   'RT @donedgley1: @Moneybox Elephant in the room is the retrospective taxation of the #LoanCharge which continues despite #Covid_19 #coronavi…',
#   'Rob6414',
#   ''],
#  [None,
#   'RT @arirangtvnews: ▪ COVID-19 IN S. KOREA\n\n* Last Updated at May, 18 - 10:30(KST) \n\n[NEWS] COVID-19 OUTBREAK : https://t.co/SQiCNCUEhu\n\n#CO…',
#   'ohohjhen',
#   'Philippines X Korea'],
#  [None,
#   'Lockdown re-imposed in AJK\nhttps://t.co/agBNfTIMsF\n#lockdown #kashmir #covid19 #coronavirus #news https://t.co/HhJ47h4W0t',
#   'ravapk',
#   'Pakistan'],
#  [None,
#   'ICYMI: #Uber has abandoned its robotic bikes and scooters project.\n\nThe #coronavirus hit ride-hailing company jetti… https://t.co/9iBzdqFzPc',
#   'TelegraphTech',
#   'London'],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'gia_marie8',
#   'USA 🇺🇸'],
#  [None,
#   'RT @NewsMobileIndia: #COVID19 | Over 5000 new cases, India witnesses biggest spike as tally breaches 96,000-mark       \n#Coronavirus \nhttps…',
#   'raghvendra_rao',
#   'New Delhi, India'],
#  [None,
#   'RT @zahahassan: American citizen and scholar #Ubai #Abboudi is being held without charge in #Israel and at risk of exposure to #coronavirus…',
#   'aymanfadel',
#   'Augusta, GA'],
#  [None,
#   'RT @kpnationalist19: Australian study finds #coronavirus “exquisitely adapted” for humans and possible it “was created by a recombination e…',
#   'MennoKools2',
#   'Zuid-Holland, Nederland'],
#  [None,
#   "RT @JerryHicksUnite: So, how far up your own arse can you get?I\n\nThis far - Person drive's 1.5 hrs to a beach with her family. Then complai…",
#   'CoronaVirusCall',
#   'North America'],
#  [None,
#   '#India has begun evacuating thousands of villagers &amp; halted port operations ahead of #CycloneAmphan, expected to hi… https://t.co/cLnm8vb2Zf',
#   'TRF_Climate',
#   'London'],
#  [None,
#   'RT @scotgov: 🖱 @YoungScot have launched a new online resource full of advice and tips on how to take care of your #MentalHealth and wellbei…',
#   'WMTYScot',
#   'Scotland, United Kingdom'],
#  [None,
#   "RT @JerryHicksUnite: So, how far up your own arse can you get?I\n\nThis far - Person drive's 1.5 hrs to a beach with her family. Then complai…",
#   'firtyfreefousan',
#   'norfolk'],
#  [None,
#   'RT @tv9gujarati: Hair Saloon and Beauty Parlours will not be allowed to open in any zone . #Gujarat #lockdown #coronavirus https://t.co/QeE…',
#   'Arjun_Aaryaveer',
#   'गुजरात, भारत'],
#  [None,
#   'RT @AJEnglish: US President Trump calls his predecessor Barack Obama “grossly incompetent” after he criticised the administration’s respons…',
#   'inquisitiveSile',
#   'Yokohama'],
#  [None,
#   'RT @nycjim: #CORONAVIRUS update 5/18/2020:\n*Italy takes huge step of reopening bars &amp; restaurants. \n*Spain records 87 deaths, first time be…',
#   'maps36',
#   'Essex'],
#  [None,
#   'RT @Geeta_Mohan: #WHA73 proceedings begin by unveiling this video.\n\n#COVID19 threatens us all, whoever we are, wherever we live.\n\n#HealthFo…',
#   'MamgainK',
#   'Dehradun, Uttrakhand'],
#  [None,
#   '@BBCNews #Coronavirus symptoms: UK adds loss of smell and taste to list https://t.co/db7rCaRdhY',
#   'jm_shepherd',
#   'Cholsey'],
#  [None,
#   'RT @portstrategy: The Coronavirus clearly is having a huge global impact, what will the lasting effect of the pandemic be on ports?\nhttps:/…',
#   'ronkeemployment',
#   'Global'],
#  [None,
#   'RT @ajc: Gov. Brian Kemp’s office issued an apology after a Georgia Public Health Department chart wrongly reported a downward trend in #co…',
#   'dahlia201',
#   'Usa'],
#  [None,
#   'RT @IndiaToday: #AndhraPradesh CM YS Jagan Mohan Reddy has ordered district officials to provide shelter, food and transportation to migran…',
#   'VakeelSaab26',
#   'PawanKalyan Trends'],
#  [None,
#   'RT @ChinaDaily: "We responded very fast... and it only took another four days to develop the first test kits for the #coronavirus," top Chi…',
#   'IrabonaJeanPaul',
#   'Rwanda'],
#  [None,
#   'RT @JamesMelville: Easing social distancing and lockdown has to happen sooner rather than later to avoid even more economic pain. But witho…',
#   'Elfiem',
#   'Wales and France'],
#  [None,
#   'RT @gergerlioglueng: Gökhan Açıkkollu died of #torture. He was summarily executed. They want to  bury him in a graveyard dubbed the cemeter…',
#   'al9ebraist',
#   ''],
#  [None,
#   'RT @Himalistan: #COVID19 in Southasia: New confirmed cases reported in Afghanistan, Bangladesh, India, Maldives, Myanmar, Nepal, Pakistan a…',
#   'rezwan',
#   'Kuala Lumpur/Dhaka'],
#  [None,
#   "RT @Join_ZOE: Loss of taste and smell (#anosmia) 👃 due to #COVID19 (as reported in our @NatureMedicine paper) has now been added to the UK'…",
#   'MrSandy_P',
#   'West Sussex '],
#  [None,
#   "RT @MazzucatoM: At 11:30 BST I'm on @BBCWorld discussing the @oxfamgb @UNAIDS letter calling for #coronavirus vaccine to be patent-free &amp; a…",
#   'Nyonya_Cat',
#   ''],
#  [None,
#   'Great @CNBC article with @FISGlobal Chief Risk Officer, Greg Montana and other tech leaders on how #coronavirus is… https://t.co/SrHvmkdFuO',
#   'MartinBoyd_FIS',
#   ''],
#  [None,
#   "BBC News - #Coronavirus : Volunteers rally behind Lochaber's Nevis Range\nhttps://t.co/S2cMelPAUV",
#   'mrsverypicky',
#   'Glasgow environs.'],
#  [None,
#   'RT @Utsava4: FDA halts the #coronavirus testing program because #Gates is under house arrest, awaiting trial. https://t.co/Dbi5l95Cql',
#   'shinethelight17',
#   'upstae NNY'],
#  [None,
#   'RT @BBCSteveR: For anyone hoping that the #coronavirus pandemic might, at least, bring East &amp; West closer together, today’s Russian papers…',
#   'bralmello',
#   'Brasil'],
#  [None,
#   '#European #Landmarks reopen but #CoronaVirus hits hard elsewhere https://t.co/0wFnOXmNxg',
#   'digitaljournal',
#   'Global'],
#  [None,
#   'RT @balalaichnitsa: For everyone interested in #DisabilityRights and #HighRiskCovid19 - new podcast on the experience of disabled communiti…',
#   'BrucePannier',
#   ''],
#  [None,
#   '@LordAshcroft .Perhaps if WW2 happened today:\n\n#Coronavirus https://t.co/9nvLqyduNd',
#   'DaveBakedPotato',
#   'UK'],
#  [None,
#   'The coronavirus has left many countries with serious economic challenges. Some countries may default on their debts… https://t.co/8fqJ0ssd7N',
#   'petpiki',
#   'Harare; Zimbabwe'],
#  [None,
#   'RT @MillerCrime: @EclecticRadical Spouse is really upset &amp; worried\n\nHe kept thanking me tonight for tweeting &amp; explaining the power dynamic…',
#   'MillerCrime',
#   ''],
#  [None,
#   "RT @AFNCCF: Join our free seminar series, 'From Crisis to Kindness', next week chaired by @PeterFonagy. We'll be talking about the #coronav…",
#   'UgsPupilsupport',
#   'Uddingston, Scotland'],
#  [None,
#   'RT @stevesilberman: How Trump and the GOP tossed away years of preparation for a global pandemic and condemned tens of thousands of America…',
#   'ApsyAngst',
#   ''],
#  [None,
#   'RT @htdelhi: #CoronavirusPandemic | Delhi CM Arvind Kejriwal to address a press conference at 5.30pm today on the #coronavirus situation.…',
#   'htTweets',
#   'India'],
#  [None,
#   'RT @JudicialWatch: “Nancy Pelosi tried to overturn voter I.D laws in 35 different states in the #Coronavirus bill!” @JudicialWatch Presiden…',
#   'MamaAng43747808',
#   ''],
#  [None,
#   '5 Insta Musicians and their Lockdown Songs, to make #Lockdown2020 a bit more bearable!\n#lockdown #lockdownsongs… https://t.co/m0omIjhss8',
#   'MirchiPlay',
#   ''],
#  [None,
#   "🚨#CHINA HAS ARRESTED HUNDREDS FOR SPEAKING OUT ABOUT #CORONAVIRUS🚨\n\n🔸If there are no cover-up, what's the need to a… https://t.co/3syveqD4ZH",
#   'paulhunghk1001',
#   'Hong Kong'],
#  [None,
#   'BBC News - Coronavirus: Tears inside Milan’s quarantine hotel #Coronavirus https://t.co/HAuUtv7pPH @BBC',
#   'ETradeSupply',
#   'Hong Kong'],
#  [None,
#   'RT @g_gosden: Lies, Boris lies, Hancock lies, Gove lies, #torybrexit lies #COVID19 #coronavirus catastrophe https://t.co/oIlQT8ei2D',
#   'SaveStBernards',
#   ''],
#  [None,
#   'RT @EconomicTimes: #Lockdown4.0 | What is allowed and what is not allowed | #Coronavirus #Live #Updates: https://t.co/AS6YycLfyj https://t.…',
#   'PRPONDUGULA',
#   'Andhra Pradesh, India'],
#  [None,
#   'RT @rtenews: "As you come into our country today you are expected to self-isolate ... but I want to put that on a legal footing and I\'m to…',
#   'Siobhan28325511',
#   ''],
#  [None,
#   'RT @ajc: Gov. Brian Kemp’s office issued an apology after a Georgia Public Health Department chart wrongly reported a downward trend in #co…',
#   'Derek_Sutton',
#   'Georgia'],
#  [None,
#   'RT @SkyNews: Poor families are more reluctant to send their children back to school during the #coronavirus pandemic despite fewer opportun…',
#   'JohnBar01132215',
#   'España'],
#  [None,
#   '#Coronavirus must be investigated as to the evil origin of the deadly contingent and why it was unleashed from Wuha… https://t.co/zmPfSZSsI4',
#   'HarryLaneGroup',
#   'USA'],
#  [None,
#   'RT @DialogueCollege: Dear Parents/Guardians! With the #coronavirus and #Lockdown, Learning on a New Dimension has been Unlocked! Check this…',
#   'abdulshehu2005',
#   'kaduna'],
#  [None,
#   'RT @EconomicTimes: “The Chinese, behind the shield of the WHO, for two months hid the virus from the world and then sent hundreds of thousa…',
#   'itzraj05',
#   'India'],
#  [None,
#   "Join me in helping #CoronaVirus victims with #Ecoin  🙏 and earn 600 Ecoins ( worth $3 ) free,  Ecoin the world's fa… https://t.co/cESLWOh6t1",
#   'Haris1549657137',
#   'Bogor Tengah'],
#  [None,
#   'RT @educationgovuk: #MentalHealthAwarenessWeek  is taking place 18 to 24 May 2020. Kindness is the new theme, in response to the #coronavir…',
#   'WestSomersetOA',
#   'West Somerset, England'],
#  [None,
#   "RT @TheDemCoalition: Dr. Rick Bright says he's trained his entire life to recognize outbreaks and viruses. But when he sounded the alarm ab…",
#   'PatAndi1',
#   ''],
#  [None,
#   'RT @WHO: In a little over 3 months, #COVID19 has changed the world in so many ways, bringing us closer together and reaffirming the importa…',
#   'dilharija',
#   'Warakapola, Sri Lanka'],
#  [None,
#   'Happy to announce as of now there are no active cases in Bhubaneswar and Jagatsinghpur. Requesting all people to st… https://t.co/ejyoabL34L',
#   'deepalidas95',
#   ''],
#  [None,
#   'RT @10DowningStreet: WATCH LIVE: #coronavirus press conference (17 May 2020)\n \nSpeakers:\n \n🔵  @AlokSharma_RDG, Business Secretary\n🔵  Prof S…',
#   'SMNTTories',
#   'Twickenham'],
#  [None,
#   'RT @ScoPoliticsNews: .@Dr_PhilippaW highlights how Scotland not being independent has limited its powers v. #coronavirus\n"..we weren’t able…',
#   'steviemcbride',
#   ''],
#  [None,
#   '#CoronavirusPandemic | Delhi CM Arvind Kejriwal to address a press conference at 5.30pm today on the #coronavirus s… https://t.co/VfP0RIlYia',
#   'htdelhi',
#   'Delhi and NCR'],
#  [None,
#   'RT @NotTheFakeKS: @WHO @DrTedros Belgium, Spain, Italy have highest #Coronavirus death rates. US deaths have grown faster in past month tha…',
#   'NotTheFakeKS',
#   'Washington, DC'],
#  [None,
#   'RT @TomthunkitsMind: WATCH THIS:\n\nEmotional Karl-Anthony Towns reveals mother is diagnosed with #Coronavirus is in a coma on a ventilator.…',
#   'dookielou',
#   ''],
#  [None,
#   'RT @SkyNews: BREAKING: The Deputy Chief Medical Officer has announced loss of taste and smell is to be added to the official list of COVID-…',
#   'MgengePhumzile',
#   'South Africa '],
#  [None,
#   'RT @NHSAbility: Washing your hands well is good protection against #Coronavirus. This is the \n@PHE_uk  #easyread poster about washing your…',
#   'ConnectintNorth',
#   'Leeds'],
#  [None,
#   'RT @joncoopertweets: Trump is afraid of germs even more than he hates dogs. Can you imagine how freaked out he must be by the #coronavirus…',
#   'ShirleySharona2',
#   'Gotham formerly the USA'],
#  [None,
#   "RT @MoeChanda: Globally 4727625 positive  cases \n315389 deaths\n\n@Ford reopening it's plants ,will provide #COVID19 testing\n\n via @CNN \n\n#co…",
#   'GoverehLevy',
#   'Zimbabwe'],
#  [None,
#   'RT @kr3at: #CoronaVirus Outside of China - 4,736,323 cases and 312,325 deaths.\n\nTo date a total of 316,959 deaths and 4,819,277 total #covi…',
#   'nobsan777',
#   ''],
#  [None,
#   "RT @CARE_SRHR: As war, intense rains and widespread disease have increased the burden on #Yemen's critically under-funded health system, th…",
#   'PlacesAtRisk',
#   ''],
#  [None,
#   'RT @kr3at: Romania reports 165 new cases bringing total confirmed cases there to 17,036 and 1,107 total deaths.\n\n#CoronaVirus #Covid19 #Cor…',
#   'nobsan777',
#   ''],
#  [None,
#   "RT @AwakenedOutlaw: This strikes a blow to China's assertion that this was a US created bio-weapon.\n\nChinese Official Confirms That #China…",
#   'JefVerwaest',
#   ''],
#  [None,
#   'RT @nabadasjsg: Happy to announce as of now there are no active cases in Bhubaneswar &amp; Jagatsinghpur. Requesting all people to stay safe an…',
#   'SatpathyP1',
#   'ଓଡିଶା,,,ରାଜଧାନୀ,,ଭୁବନେଶ୍ଵର,,'],
#  [None,
#   'Here German Marxists on: #Germany - The Power House of Europe and #Coronavirus Tuesday 19 May from the CWI https://t.co/GOetGxDflR #COVID19',
#   'NorthSocialist',
#   ''],
#  [None,
#   'RT @myfairobserver: The stress of COVID-19 on the global economy will expand the market for fintech and accelerate the pace at which it is…',
#   'GOjedaVega',
#   'United States'],
#  [None,
#   '#COVID19 | Over 5000 new cases, India witnesses biggest spike as tally breaches 96,000-mark       \n#Coronavirus \nhttps://t.co/upQot2uOhZ',
#   'NewsMobileIndia',
#   'India'],
#  [None,
#   'RT @kr3at: Switzerland reports 10 new cases bringing total confirmed cases there to 30,597 and 1,881 total deaths.\n\n#CoronaVirus #Covid19 #…',
#   'nobsan777',
#   ''],
#  [None,
#   'RT @guy_ingerson: Looks like our @ScotGP MSPs (with your support!) have won a big concession from the Scottish Government. \n\nTax dodging co…',
#   'AberdeenGreens',
#   'Aberdeen City & Shire'],
#  [None,
#   'RT @Winnie_Byanyima: We cannot repeat what happened years ago when HIV treatments were found. People in rich countries were getting well wh…',
#   'DorothyKaine',
#   'Uganda'],
#  [None,
#   'RT @TomthunkitsMind: USING A SWAT TEAM TO COMBAT THE #CORONAVIRUS IS NOVEL FOR SURE.\nhttps://t.co/NeYDKs736V 03\n#Resist',
#   'Atseawall',
#   'Florida '],
#  [None,
#   'RT @DineshDSouza: I feel the same way about masks as I do about Muslim women putting on the hijab. If you want to wear one, there’s nothing…',
#   'JonEricAdamsOne',
#   ''],
#  [None,
#   'RT @kr3at: Kansas reports 2 new cases bringing total confirmed cases there to 7,953 and 195 total deaths.\n\n#CoronaVirus #Covid19 #CoronaVir…',
#   'nobsan777',
#   ''],
#  [None,
#   'RT @StefSimanowitz: “PM’s virus inspections at work don’t exist.”\n\nThe Health &amp; Safety Executive say they have stopped all spot inspections…',
#   'pocketricks',
#   'North West, England'],
#  [None,
#   "RT @toisports: .@anjum_moudgil welcomes government's decision to re-open stadiums \n\nREAD: https://t.co/7oT2CQoc7H\n\n#Lockdown #Shooting #Anj…",
#   '1d_swiftie007',
#   'Mumbai, Maharashtra'],
#  [None,
#   'RT @10DowningStreet: WATCH LIVE: #coronavirus press conference (16 May 2020)\n\nSpeakers:\n🔵@GavinWilliamson, Education Secretary\xa0\n🔵Dr Jenny H…',
#   'SMNTTories',
#   'Twickenham'],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   'KBRmaterial',
#   'Manhattan, NY'],
#  [None,
#   'RT @ManMundra: India should now release daily data on #Coronavirus in detailed form, instead of just one set of numbers. \n\nInfected: Age gr…',
#   'Mi91423569',
#   ''],
#  [None,
#   'RT @kr3at: North Carolina reports 14 new cases and 2 new deaths bringing total confirmed cases there to 18,673 and 686 total deaths.\n\n#Coro…',
#   'nobsan777',
#   ''],
#  [None,
#   'RT @EdinShieldForce: Do you need face shields? We make them and have lots. Please send us a request!\n\n@edinspotlight @EdinburghLive_\n\n#COVI…',
#   'jesslynnrose',
#   'Birmingham/どこでも'],
#  [None,
#   'RT @RosMathieson: A pretty major warning that this thing keeps circling back around like a hungry shark: Some 108 million people in #China’…',
#   'KimBarrett2',
#   'Ontario, Canada'],
#  [None,
#   'RT @SkyNews: The daughter of a man who died with suspected #coronavirus has told Sky News she wants to know who signed off on a government…',
#   'KaraChrome',
#   'United Kingdom'],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'nice_centurion',
#   '🌍Rom, Latium🌞'],
#  [None,
#   'RT @WinnersChapelNL: THE PROPHETIC DECLARATIONS &amp; DECREES (On #Covid19 #Cancer #SickleCellAnemia #HepatitisB And Many More! ]) FROM THIS WE…',
#   'roinuj_bless',
#   'Meru, Kenya'],
#  [None,
#   "RT @HumanRightsCtte: 1/5 At 2:30pm today, we'll be hearing from parents of young people who are autistic and/or have learning disabilities…",
#   'syeb75',
#   'Blackpool'],
#  [None,
#   'RT @theautismdad: How much longer can you continue living under the #COVID19 restrictions?\nPlease Retweet for a larger sample \n\n#coronaviru…',
#   'lutznobody2',
#   'Florida, USA'],
#  [None,
#   "RT @JerryHicksUnite: So, how far up your own arse can you get?I\n\nThis far - Person drive's 1.5 hrs to a beach with her family. Then complai…",
#   'Tedldoo',
#   'NW England'],
#  [None,
#   'RT @FirstEditCam: Is Covid-19, the new coronavirus tearing across the globe, masculine or feminine? In practical terms, should the French u…',
#   'VadimKadyrov',
#   'Ukraine'],
#  [None,
#   'RT @AndyOstroy: @realDonaldTrump It won’t be such “very good news” when the numbers spike because of reckless, irresponsible, premature #re…',
#   'HK2K16_',
#   "Where Trumpsters aren't."],
#  [None,
#   'RT @FrankLuntz: Here are the doctors mentioned in this story – follow them and retweet them to spread good, intelligent info during the #co…',
#   'rnitsch',
#   'Berlin, Deutschland'],
#  [None,
#   'RT @joncoopertweets: Trump is afraid of germs even more than he hates dogs. Can you imagine how freaked out he must be by the #coronavirus…',
#   'MarkoSilberhand',
#   'Bayern, Deutschland'],
#  [None,
#   'RT @kpnationalist19: Australian study finds #coronavirus “exquisitely adapted” for humans and possible it “was created by a recombination e…',
#   'markhor95367491',
#   'Rogers MN'],
#  [None,
#   'RT @EdinShieldForce: Do you need face shields? We make them and have lots. Please send us a request!\n\n@edinspotlight @EdinburghLive_\n\n#COVI…',
#   'jiggy_pete',
#   'Glasgow'],
#  [None,
#   'RT @IshitaBhatiaTOI: BREAKING: Three new cases test positive in Meerut; taly reaches 331 (incl one from Kanpur)\n#Meerut #Coronavirus',
#   'TarunVashishth',
#   'Meerut( West U.P) India'],
#  [None,
#   'Services\n.\n.\n.\n.\n.\n#hoursofoperation #veterinary #covid19 #changesdaily #covidvet #stayopen #coronavirus #quarantine https://t.co/67DJNYqT4g',
#   'equine_t',
#   'Bulgaria'],
#  [None,
#   'RT @SkyNews: BREAKING: The Deputy Chief Medical Officer has announced loss of taste and smell is to be added to the official list of COVID-…',
#   'recce_trooper',
#   'Cheshire, UK'],
#  [None,
# ...
#   'corona_tracking',
#   ''],
#  [None,
#   'RT @jamie_saris: If sniffing out #coronavirus is possible, then dogs r an expensive, awkward, high maintenance animal to use. @HeroRATs hav…',
#   'sundogme',
#   'Plymouth Europe '],
#  [None,
#   'Both @WHO and @UNICEF recommend that you keep breastfeeding if you think you might have #coronavirus, but you shoul… https://t.co/hwvlqOzImv',
#   'UNICEFROSA',
#   'Kathmandu, Nepal'],
#  [None,
#   'RT @DrThomasPaul: Wake up world. NOW. \n\n#BillGatesBioTerrorist is "EXCITED" to forcibly inject everyone with dangerous vaccines with microc…',
#   'peterpobjecky',
#   'Gillingham,UK'],
#  [None,
#   'RT @nichtaufrezept: 1/2 The making of a #guideline in the middle of a pandemic:  the SSC COVID-19 guidelines represent an first step toward…',
#   'JAMAInternalMed',
#   'Chicago, IL'],
#  [None,
#   'Hope In The Worldwide Storm!\nFull video -&gt; \u200bhttps://t.co/NmgB7lVpI9\u200b \u200b#30days30videos\u200b \u200b#MessageToChristians\u200b… https://t.co/qVAhhWLOoh',
#   'MusicLov3rzMag_',
#   'Worldwide'],
#  [None,
#   '"We responded very fast... and it only took another four days to develop the first test kits for the #coronavirus,"… https://t.co/StlpAZmFWX',
#   'ChinaDaily',
#   'Beijing, China'],
#  [None,
#   'RT @SkyNews: BREAKING: The Deputy Chief Medical Officer has announced loss of taste and smell is to be added to the official list of COVID-…',
#   'citizens_arise',
#   'Zimba'],
#  [None,
#   'RT @CMOWales: From today, all individuals should self-isolate if they develop a new continuous cough or fever or anosmia.\n\nAnosmia is the l…',
#   'LeadinginWales',
#   'Wales, UK'],
#  [None,
#   'RT @nycjim: #CORONAVIRUS update 5/18/2020:\n*Italy takes huge step of reopening bars &amp; restaurants. \n*Spain records 87 deaths, first time be…',
#   'diannesopinion',
#   'United States'],
#  [None,
#   'Yes, it’s important to know what’s happening with #coronavirus - but don’t let it hide other important news. What i… https://t.co/xSJVxaFfBM',
#   'JChaseWilliams',
#   'Taipei City, Taiwan'],
#  [None,
#   'Citizens are now allowed to enter and leave #Marneuli. Despite lifted restrictions, thermal imaging will continue a… https://t.co/Eeq75v999m',
#   'FormulaGe',
#   'Georgia'],
#  [None,
#   'RT @RepChrisSmith: Global Magnitsky sanctions should be imposed on those Chinese government officials who lied and suppressed the truth abo…',
#   'Heawo4',
#   ''],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'JenniferDonels2',
#   'Indiana, USA'],
#  [None,
#   'RT @Mithamo_King: Kawangware. Eastleigh. Cases just disappeared. Gigh numbers just when the curfew and lockdown are up for review. #coronav…',
#   'Sabato_Fred',
#   'Nairobi - Kenya'],
#  [None,
#   'RT @SkyNews: BREAKING: The Deputy Chief Medical Officer has announced loss of taste and smell is to be added to the official list of COVID-…',
#   'truebluenig09',
#   'West Yorks.'],
#  [None,
#   'RT @NewsLineIFE: #BreakingNews : Communist #China on Friday (May 15) admitted to destroying Wuhan #coronavirus #COVID19 samples in early Ja…',
#   'Chinmay07662566',
#   ''],
#  [None,
#   'RT @doctorshaib: With my old friends @BBCWiltshire with @marieklennon. Join our conversation about #COVID19, #Coronavirus. Schools reopenin…',
#   'hearsncheers',
#   ''],
#  [None,
#   'Time are tough right now but there is a supercalifragilisticexpialidocious someone coming to the rescue! I loved wo… https://t.co/2fqbUcW05g',
#   'irenesilvino',
#   'London, UK'],
#  [None,
#   'RT @Seoul_James_146: 🚨 That footage of the 31st patient attending service at the #DaeguChurch has been deleted\n\n✅ Q&amp;A on Shincheonji Church…',
#   'kgj2323',
#   '한ㆍㄱ'],
#  [None,
#   'RT @BarbaraForeman: This is the wrong time to change the message. #NicolaSturgeon is clear and exemplary #Coronavirus #StayAtHome',
#   'NigelKi15345343',
#   ''],
#  [None,
#   'RT @ManMundra: India should now release daily data on #Coronavirus in detailed form, instead of just one set of numbers. \n\nInfected: Age gr…',
#   'Rohan80658798',
#   ''],
#  [None,
#   'The little green men must be out of their minds "traveling" to #brazil in this particular time, they were like:… https://t.co/ORedji0zbj',
#   'Minime171',
#   'Saturn'],
#  [None,
#   'The #coronavirus\xa0pandemic must be tackled on all fronts, all over the world. I am grateful to #Slovakia for helping… https://t.co/WtyF9RHTk4',
#   'JanezLenarcic',
#   ''],
#  [None,
#   'RT @EconomicTimes: “The Chinese, behind the shield of the WHO, for two months hid the virus from the world and then sent hundreds of thousa…',
#   'Himansu_Aajtak',
#   'Bhubaneswar,Odisha'],
#  [None,
#   'RT @Seoul_James_146: 📌 Is a Shincheonji member the cause of the spread of COVID-19 at Kmadi Hospital in Daegu⁉️⁉️\n\n✅ Q&amp;A on Shincheonji Chu…',
#   'kgj2323',
#   '한ㆍㄱ'],
#  [None,
#   '#UKaid is supporting small and medium sized charities contributing to the #coronavirus response overseas, including… https://t.co/SFnKujYabR',
#   'JamesCleverly',
#   'North Essex'],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   'Ka_Asor',
#   'Abuja'],
#  [None,
#   '@OshebengAlphieK @FIFAWorldCup @rugbyworldcup @cricketworldcup Australia, New Zealand, South Africa are amongst of… https://t.co/Orkd7pXhHZ',
#   'RichmondDayel',
#   ''],
#  [None,
#   'RT @CSCarrigan: #Howto cope with the #loneliness of #coronavirus, what a #medicalintuitive wants you to know now: https://t.co/Wnh1ff7T2f #…',
#   'JJohannesM51',
#   'Finland'],
#  [None,
#   "Looking to #volunteer in #Nottingham during the #coronavirus crisis? Register with us and we'll connect you with lo… https://t.co/XioKxn4ePE",
#   'VolunteerNG',
#   'Nottingham'],
#  [None,
#   'RT @Ozkok_A: #BELGIUM - Protest against the Prime Minister Sophie Wilmes, hospital St. Pierre in Brussels.\n\n#coronavirus https://t.co/fFsfg…',
#   'arturcastilho',
#   'Macae, RJ Brasil'],
#  [None,
#   'RT @HMRCgovuk: Are you a business with fewer than 250 employees? Did you know that the cost of providing 2 weeks of #coronavirus related St…',
#   'DiskelLtd',
#   'UK , International'],
#  [None,
#   'RT @ahmedabadmirror: Gujarat’s largest #Covid19 hospital urgently seeks full-fledged ventilators from Centre\n\n#coronavirus #coronavirusinin…',
#   'YTSAZT',
#   ''],
#  [None,
#   "#China's leader, Gen Sec Xi will speak at the meeting of the World Health Assembly (WHA) - the decision making body… https://t.co/scd8rtpN3j",
#   'StephenMcDonell',
#   'Beijing'],
#  [None,
#   'RT @pradeepraiindia: No one can figure out which connection is going to which unit other than the great electrician , similarly many polici…',
#   'RajShriAPN',
#   'New Delhi, India'],
#  [None,
#   'RT @KanchanGupta: A snake oil salesman called Ramanan Lakshminarayanan was all over media predicting "300-500 million #COVID19 cases and 1-…',
#   'Kumar22072',
#   ''],
#  [None,
#   'RT @ahmedabadmirror: Gujarat’s largest #Covid19 hospital urgently seeks full-fledged ventilators from Centre\n\n#coronavirus #coronavirusinin…',
#   'NaikRaviraj',
#   ''],
#  [None,
#   'Lockdown 4.0: States can’t dilute guidelines; can only make them stricter, says MHA      \n\n#Lockdown4 #Coronavirus… https://t.co/Q9epgMnmWP',
#   'NewsMobileIndia',
#   'India'],
#  [None,
#   'President Putin had promised in his televised address that  medic workers treating #Coronavirus patients would rece… https://t.co/C6DIOomi5R',
#   'mbk_center',
#   ''],
#  [None,
#   'RT @mrmikecowan: Michael Gove cites Denmark as getting their kids back to school effectively.\nDenmark have had 543 deaths and 10,000 cases.…',
#   'MatthewR0226',
#   'Nottingham|Liverpool'],
#  [None,
#   'COVID-19: Over a million likely to be evacuated due to Cyclone Amphan #Coronavirus https://t.co/vzmkOCXYHi',
#   'RonakShah',
#   'India'],
#  [None,
#   'RT @ajc: Gov. Brian Kemp’s office issued an apology after a Georgia Public Health Department chart wrongly reported a downward trend in #co…',
#   'authenticFNL',
#   'Florida, USA'],
#  [None,
#   'RT @retailgazette: Retailers could be banned from paying dividends or buying back shares as the government revises coronavirus loan scheme.…',
#   'SteveMurrayM4',
#   'Manchester UK'],
#  [None,
#   'RT @EconomicTimes: “The Chinese, behind the shield of the WHO, for two months hid the virus from the world and then sent hundreds of thousa…',
#   'Pradeepgrana',
#   ''],
#  [None,
#   "It's #MentalHealthAwarenessWeek and #Kettering Borough businesses and community leaders came together with a messag… https://t.co/qwqm7HYxGW",
#   'simoncox73',
#   'Kettering, England'],
#  [None,
#   'WARNING: Do not spray disinfectants at other people! Not outside, not indoors! @WHO\xa0 just issued new guidance sayin… https://t.co/alNEPkJnhT',
#   'MorningExp',
#   'Atlanta, GA'],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   'O_Niyif',
#   'Ilorin, Nigeria'],
#  [None,
#   'RT @AlArabiya_Eng: Most of the newly reported #coronavirus cases in #Oman were of expatriates, the Ministry of Health says. \n\nhttps://t.co/…',
#   'SuratVintage',
#   ' دبي، الامارات العربية المتحدة'],
#  [None,
#   'RT @HMRCgovuk: Are you a business with fewer than 250 employees? Did you know that the cost of providing 2 weeks of #coronavirus related St…',
#   'nickb303',
#   ''],
#  [None,
#   'RT @veryvirology: Update on Artemisia Annua! #coronavirus #COVID__19 \n\nhttps://t.co/ixOCAz0CW1',
#   'patricio_javi',
#   'Guayaquil, Ecuador'],
#  [None,
#   'Avoid public surfaces.\n\n#earth #pandemic #virus #coronavirus #covid19 https://t.co/E2RFW7Bi18',
#   'GaianLight',
#   'Gaia 🌍🌳'],
#  [None,
#   'RT @BarclaysAccess: We’ve known for a long time that #inclusion &amp; #accessibility is good for business, as well as being good for society. A…',
#   'ktculture',
#   'london'],
#  [None,
#   'BBC News - #Coronavirus symptoms: UK adds loss of smell and taste to list\nhttps://t.co/ttGqhiFnH0',
#   'mrsverypicky',
#   'Glasgow environs.'],
#  [None,
#   'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…',
#   'RichardChaby',
#   'Wellington, FL'],
#  [None,
#   "Former #WHO board member warns world against #coronavirus 'vaccine nationalism'\n\nhttps://t.co/nKlCPJKxqb",
#   'OneStepBayond',
#   'Freiland bei Deutschlandsberg'],
#  [None,
#   "RT @DrDenaGrayson: ⚠️Dr. Rick Bright—former top government #vaccine expert ousted by @realDonaldTrump: “We don't yet have a national strate…",
#   'Zachary03699160',
#   'Haslett, MI'],
#  [None,
#   'RT @HMRCgovuk: Are you a business with fewer than 250 employees? Did you know that the cost of providing 2 weeks of #coronavirus related St…',
#   '54StJamesStreet',
#   'Liverpool'],
#  [None,
#   'RT @Psychedup_: @PsychNews As Dr.hoof writes... "This pandemic is the biggest psychological experiment and we are the one who are going to…',
#   'marisslinsalata',
#   'New York, USA'],
#  [None,
#   'RT @EconomicTimes: “The Chinese, behind the shield of the WHO, for two months hid the virus from the world and then sent hundreds of thousa…',
#   'kaintman',
#   'India'],
#  [None,
#   "Not even #NewZealand's Prime Minister #JacindaArdern  was exempt from her own\xa0#Coronavirus\xa0restrictions after she w… https://t.co/toMmzaQol5",
#   'Nelsonrajupb',
#   'Chennai, India'],
#  [None,
#   'RT @ChinaDaily: The British Chinese and the people in East Asian communities in the UK, who have been victims of #racism and #hatecrime, ha…',
#   'HkSpectrum',
#   ''],
#  [None,
#   'RT @CBSThisMorning: A U.S. Postal Service worker felt bad for the high school seniors missing out on graduation due to the #coronavirus cri…',
#   'Truly_U_',
#   'United States'],
#  [None,
#   "RT @DEPTH_LSHTM: Today's #mondaymotivation is this @bmj_latest article arguing that the views of patients &amp; the public should be included i…",
#   'ssega2001',
#   'Kampala, Uganda| Antwerp, Belgium| Cape Town, South Africa.'],
#  [None,
#   'RT @the_hindu: As per reports submitted by collectors of all 28 districts, the situation is yet to be brought under complete control and th…',
#   'AbbojuPrashant4',
#   'Hyderabad, India'],
#  [None,
#   'No birthday hugs for Michelle this year-#Coronavirus crashed that part of the party! We didn’t ask the number so we… https://t.co/MpOGS8peNA',
#   'plittletvguy',
#   'Providence, RI'],
#  [None,
#   'RT @dswpti: Another endorsement of @ImranKhanPTI  vision. Empathy must be part of decision making process. #coronavirus',
#   'salman0800',
#   'Unknown'],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   'saadohn',
#   'Zaria, kaduna state Nigeria'],
#  [None,
#   '. \u2066@healthdpt\u2069 \u2066@MattHancock\u2069 \u2066@DHSCgovuk \u2066@10DowningStreet\u2069 \u2066@BorisJohnson\u2069 \nMy local doctor told me this weeks ag… https://t.co/mLkU6unrVB',
#   'CharmsOfLight',
#   'Buckinghamshire, UK'],
#  [None,
#   'RT @jduflou: @abc730 And this is why economics is called the dismal science. What miserable people! #coronavirus',
#   'addcount',
#   'Mount Gambier, South Australia'],
#  [None,
#   'RT @KJWatersAuthor: #Coronavirus got you down?  Escape with this superb #Timetravel "This series has it all! Romance, intrigue, time travel…',
#   'papriddey',
#   ''],
#  [None,
#   'RT @EllaaaCruzzz: "Please Sign This Petition Against Nancy Pelosi’s un-American $3 Trillion Coronavirus Relief Package (Which All Goes To I…',
#   'parb_patriv',
#   'United States of America'],
#  [None,
#   'RT @kpnationalist19: Australian study finds #coronavirus “exquisitely adapted” for humans and possible it “was created by a recombination e…',
#   'gray34758',
#   'Poinciana, FL'],
#  [None,
#   'RT @Complex: Magic Johnson’s company will reportedly fund $100 million in loans to help women and minority-owned small businesses during #c…',
#   'MarchesdElodie',
#   'Littoral, Cameroon'],
#  [None,
#   'RT @JudicialWatch: “Nancy Pelosi tried to overturn voter I.D laws in 35 different states in the #Coronavirus bill!” @JudicialWatch Presiden…',
#   'priceys',
#   ''],
#  [None,
#   'RT @TeamworkSelect: #Coronavirus - How Exposed Is Your Job?\n\nPublished on the BBC, the job ranker rates the exposure to disease and the pro…',
#   'Derek_GTA',
#   'Gloucestershire'],
#  [None,
#   '@SkyNews @laurabundock Losing your sense of smell or taste is a symptom of coronavirus, UK officials finally admit… https://t.co/YyLaXiwggd',
#   'WorldCOVID19',
#   'United Kingdom'],
#  [None,
#   'Democrats worry about @realDonaldTrump not wearing a mask even though he is tested every day and is #coronavirus ne… https://t.co/j6wMYAlizS',
#   'BruceMajors4',
#   'mid-Atlantic Appalachia'],
#  [None,
#   'RT @SanelaWPLG: EVERYTHING YOU NEED TO KNOW: Phase 1 reopening rundown for #MiamiDade, #Broward counties #coronavirus https://t.co/oLRiJ6Zi…',
#   'mcadebate',
#   'Hollywood, FL'],
#  [None,
#   "RT @MarcherLord1: Imagine thinking that teaching maths to 8yr olds is a 'front line' role in the #coronavirus outbreak?\n\nTell that to an IC…",
#   'NoExcusesJim',
#   ''],
#  [None,
#   'RT @Tombx7M: Destroying the fake news\nOne fact at a time\n\n#Ccot #KAG2020 #Trump2020 #SaturdayThoughts #COVID #coronavirus #Tcot #Cnnsotu #F…',
#   'silver_fox9',
#   'BaconLand'],
#  [None,
#   'RT @BamaiyiDanladi: My Name Is Bamaiyi Danladi, I Am A Naturally Born Creative Artist Form Kaduna State Nigeria, \n*Maintain Social Distance…',
#   'CoronaVirusCall',
#   'North America'],
#  [None,
#   'RT @nycjim: New #coronavirus cases in Russia under 9,000 for first time since 1 May; country has second-highest number of cases behind the…',
#   'CovfefeTwaffle',
#   ''],
#  [None,
#   "RT @DrDenaGrayson: ⚠️Dr. Rick Bright—former top government #vaccine expert ousted by @realDonaldTrump: “We don't yet have a national strate…",
#   'renbri13542',
#   ''],
#  [None,
#   'RT @SkyNews: Poor families are more reluctant to send their children back to school during the #coronavirus pandemic despite fewer opportun…',
#   'NgoiePado',
#   ''],
#  [None,
#   "RT @MOFA_Taiwan: Minister Wu boils the need for #Taiwan's @WHO &amp; #WHA73 participation down to 1 concept: fairness. Watch his interview with…",
#   'Star20861',
#   '']]

# %%
import pandas as pd

# %%
tweet_df = pd.DataFrame(data = tweet_details,columns=['geo','text','user','location'])
pd.set_option('max_colwidth',800)
tweet_df.head(20)
# Out:
#      geo  ...                  location
# 0   None  ...             Jaipur, India
# 1   None  ...       book/author info at
# 2   None  ...            United Kingdom
# 3   None  ...                      Kyiv
# 4   None  ...                   Ireland
# 5   None  ...
# 6   None  ...              Aforika  ...
# 7   None  ...                     World
# 8   None  ...
# 9   None  ...  Rustenburg, South Africa
# 10  None  ...            United States
# 11  None  ...
# 12  None  ...         Texas or Montana
# 13  None  ...
# 14  None  ...
# 15  None  ...    Kurdistan Region-Erbil
# 16  None  ...
# 17  None  ...              Persian Gulf
# 18  None  ...               Merseyside.
# 19  None  ...                 Edinburgh
#
# [20 rows x 4 columns]
