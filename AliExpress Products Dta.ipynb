# %%
import requests
from bs4 import BeautifulSoup as soup
from requests_html import AsyncHTMLSession

# %%
# !pip install pyppdf

import pyppdf.patch_pyppeteer
# Out:
# ...
#   Created wheel for pyppdf: filename=pyppdf-0.0.12-cp37-none-any.whl size=11555 sha256=3883eede9bf8c5fabc6123c588e6cd55aa381c88c576b55aa864950670faf3b8
#   Stored in directory: C:\Users\Manoj\AppData\Local\pip\Cache\wheels\62\70\18\d9ecaa8a982c5d069156d6351720b02999402f62a1fe7b50d0
# ...
#   Created wheel for litereval: filename=litereval-0.0.11-cp37-none-any.whl size=6032 sha256=ad2ea6b77ec9e6540d5673e214fb08f04100c90c08cf1cd086f2edf94d860b0c
#   Stored in directory: C:\Users\Manoj\AppData\Local\pip\Cache\wheels\e6\e2\5a\068517d8e6513cb6c83d33496750b94b0da1905223df192d4b
# Successfully built pyppdf litereval
# ...

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36'}

# %%
cookies={'ali_apache_id':'10.182.248.34.1591291944558.176027.3','x_csrf':'12e61xymf_6lh','acs_rt':'19267929856047dbb3bbaeb46e13367f','intl_locale':'en_US','JSESSIONID':'E98FF428CE4A3989EA658C70D11FB2A7'}

# %%
html = requests.get('https://www.aliexpress.com/item/32867673917.html?spm=a2g0o.productlist.0.0.3154230d1ytBWE&algo_pvid=6ae5a1f8-b315-44cf-998d-2e38664bd259&algo_expid=6ae5a1f8-b315-44cf-998d-2e38664bd259-0&btsid=0ab6fb8315916032919967411e2635&ws_ab_test=searchweb0_0,searchweb201602_,searchweb201603_',headers=header,cookies=cookies)

# %%
bsobj = soup(html.content)

# %%
bsobj
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <title>ASUS Video Card Original GT630 1GB 128Bit GDDR5 Graphics Cards for nVIDIA VGA Cards Geforce GT 630 Hdmi Dvi Used On Sale|Graphics Cards|   - AliExpress</title>
# <meta content="Graphics Cards,Computer &amp; Office, Cheap Graphics Cards,High Quality Computer &amp; Office,Graphics Cards, , " name="keywords"/>
# <meta content="Cheap Graphics Cards, Buy Quality Computer &amp; Office Directly from China Suppliers:ASUS Video Card Original GT630 1GB 128Bit GDDR5 Graphics Cards for nVIDIA VGA Cards Geforce GT 630 Hdmi Dvi Used On Sale
# Enjoy ✓Free Shipping Worldwide! ✓Limited Time Sale ✓Easy Return." name="description"/>
# <meta content="8daa66079a8aa29e-f219f934a1051f5a-ge19f8e1eaa3bf94b-e" name="google-translate-customization"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# ...

# %%
bsobj.findAll('span',{'calss':'product-price-value'})
# Out:
# []

# %%
asession = AsyncHTMLSession()

r = await asession.get('https://www.aliexpress.com/item/32867673917.html?spm=a2g0o.productlist.0.0.3154230d1ytBWE&algo_pvid=6ae5a1f8-b315-44cf-998d-2e38664bd259&algo_expid=6ae5a1f8-b315-44cf-998d-2e38664bd259-0&btsid=0ab6fb8315916032919967411e2635&ws_ab_test=searchweb0_0,searchweb201602_,searchweb201603_')

# %%
await r.html.arender()

# %%
h1 = r.html.find('h1')
h1[0].text
# Out:
# 'ASUS Video Card Original GT630 1GB 128Bit GDDR5 Graphics Cards for nVIDIA VGA Cards Geforce GT 630 Hdmi Dvi Used On Sale'

# %%
rating = r.html.find('.overview-rating-average')
rating[0].text
# Out:
# '4.8'

# %%
rating_count = r.html.find('.product-reviewer-reviews')
rating_count[0].text.replace('Reviews','').strip()
# Out:
# '20'

# %%
price = r.html.find('.product-price-value')
price[0].text.replace('US','').strip()
# Out:
# '$36.87'
