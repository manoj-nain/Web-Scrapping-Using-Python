# %%
import json

# %%
with open('mdrive.json') as f:
  data = json.load(f)

# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
print(data)
# Out:
# {'type': 'service_account', 'project_id': 'capable-memory-277611', 'private_key_id': '839009c29ff0c73a3508bef024ce7b3e6de01480', 'private_key': '-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n', 'client_email': 'manojjupyter@capable-memory-277611.iam.gserviceaccount.com', 'client_id': '102004337320420382271', 'auth_uri': 'https://accounts.google.com/o/oauth2/auth', 'token_uri': 'https://oauth2.googleapis.com/token', 'auth_provider_x509_cert_url': 'https://www.googleapis.com/oauth2/v1/certs', 'client_x509_cert_url': 'https://www.googleapis.com/robot/v1/metadata/x509/manojjupyter%40capable-memory-277611.iam.gserviceaccount.com'}

# %%
pip install gspread oauth2client
# Out:
# Collecting gspread
#   Downloading https://files.pythonhosted.org/packages/9c/ba/bc8de4f5077bd34bc873bdd67a89cb29c4f181abba8a836d2c6a0a142365/gspread-3.6.0-py3-none-any.whl
# Collecting oauth2client
#   Downloading https://files.pythonhosted.org/packages/95/a9/4f25a14d23f0786b64875b91784607c2277eff25d48f915e39ff0cff505a/oauth2client-4.1.3-py2.py3-none-any.whl (98kB)
# Collecting google-auth>=1.12.0 (from gspread)
#   Downloading https://files.pythonhosted.org/packages/12/a3/2695fdcda305ea85c43ebd2a4d1429f3c7e897c7cf9045a8c378e1115a15/google_auth-1.15.0-py2.py3-none-any.whl (89kB)
# Collecting google-auth-oauthlib>=0.4.1 (from gspread)
#   Downloading https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.2.1 in c:\users\manoj\anaconda3\lib\site-packages (from gspread) (2.23.0)
# Collecting httplib2>=0.9.1 (from oauth2client)
#   Downloading https://files.pythonhosted.org/packages/b3/ad/d9d9331850ea5bd4f5cb8c650c0bfa119a4abd6b0ad7c45b6506bc979fc0/httplib2-0.18.1-py3-none-any.whl (95kB)
# Requirement already satisfied: six>=1.6.1 in c:\users\manoj\anaconda3\lib\site-packages (from oauth2client) (1.12.0)
# Collecting rsa>=3.1.4 (from oauth2client)
#   Downloading https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\manoj\anaconda3\lib\site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\manoj\anaconda3\lib\site-packages (from oauth2client) (0.4.8)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth>=1.12.0->gspread)
#   Downloading https://files.pythonhosted.org/packages/b3/59/524ffb454d05001e2be74c14745b485681c6ed5f2e625f71d135704c0909/cachetools-4.1.0-py3-none-any.whl
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\manoj\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (41.4.0)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib>=0.4.1->gspread)
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread) (2019.9.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread) (1.24.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread) (3.0.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread)
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Installing collected packages: rsa, cachetools, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, gspread, httplib2, oauth2client
# Successfully installed cachetools-4.1.0 google-auth-1.15.0 google-auth-oauthlib-0.4.1 gspread-3.6.0 httplib2-0.18.1 oauth2client-4.1.3 oauthlib-3.1.0 requests-oauthlib-1.3.0 rsa-4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials


# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/drive.file','https://www.googleapis.com/auth/spreadsheets']
creds = ServiceAccountCredentials.from_json_keyfile_name('mdrive.json', scope)
client = gspread.authorize(creds)


# Find a workbook by name and open the first sheet
# Make sure you use the right name here.
sheet = client.open("webscrap").sheet1
spreadsheet_key = '1F3hTV2t99Y2R7oVIBA96hH_9ZRqRKqYG-SqfKO000PQ'

# %%
import bs4
import urllib.request
from urllib.request import urlopen 
from bs4 import BeautifulSoup as soup

# %%
html = urlopen('https://en.wikipedia.org/wiki/List_of_largest_recorded_music_markets')
bsobj = soup(html.read())
tbody = bsobj('table',{'class':'wikitable plainrowheaders sortable'})[0].findAll('tr')
xl = []
for row in tbody:
    cols = row.findChildren(recursive = False)
    cols = [element.text.strip() for element in cols]
    
    xl.append(cols)
    print(cols)
# Out:
# ['Ranking', 'Market', 'Retail value  US $ (millions)', 'Physical', 'Digital', 'Performance Rights', 'Synchronization']
# ['1', 'United States', '5,916.1', '15%', '75%', '7%', '3%']
# ['2', 'Japan', '2,727.5', '72%', '21%', '5%', '1%']
# ['3', 'Germany', '1,323.1', '43%', '36%', '20%', '1%']
# ['4', 'United Kingdom', '1,310.7', '30%', '50%', '18%', '2%']
# ['5', 'France', '925.1', '36%', '34%', '27%', '3%']
# ['6', 'South Korea', '494.4', '37%', '59%', '4%', '0%']
# ['7', 'Canada', '437.2', '21%', '65%', '14%', '1%']
# ['8', 'Australia', '412.9', '19%', '68%', '11%', '2%']
# ['9', 'Brazil', '295.8', '5%', '60%', '34%', '0%']
# ['10', 'China', '292.3', '3%', '90%', '7%', '0%']
# ['11', 'Netherlands', '269.5', '22%', '50%', '27%', '0%']
# ['12', 'Italy', '247.9', '39%', '36%', '22%', '3%']
# ['13', 'Spain', '205.8', '26%', '49%', '24%', '2%']
# ['14', 'Sweden', '199.5', '10%', '72%', '17%', '1%']
# ['15', 'Norway', '139.0', '9%', '71%', '19%', '1%']
# ['16', 'Denmark', '137.9', '7%', '56%', '36%', '1%']
# ['17', 'Switzerland', '137.8', '27%', '52%', '21%', '0%']
# ['18', 'Mexico', '137.0', '15%', '79%', '4%', '1%']
# ['19', 'India', '130.7', '7%', '78%', '9%', '6%']
# ['20', 'Argentina', '130.0', '8%', '31%', '60%', '1%']
# ['', 'Global total', '17,270', 'n/a', 'n/a', 'n/a', 'n/a']

# %%
import pandas as pd
df = pd.DataFrame(data = xl)
df
# Out:
#           0               1                              2         3        4  \
# 0   Ranking          Market  Retail value  US $ (millions)  Physical  Digital
# 1         1   United States                        5,916.1       15%      75%
# 2         2           Japan                        2,727.5       72%      21%
# 3         3         Germany                        1,323.1       43%      36%
# 4         4  United Kingdom                        1,310.7       30%      50%
# 5         5          France                          925.1       36%      34%
# 6         6     South Korea                          494.4       37%      59%
# 7         7          Canada                          437.2       21%      65%
# 8         8       Australia                          412.9       19%      68%
# 9         9          Brazil                          295.8        5%      60%
# 10       10           China                          292.3        3%      90%
# 11       11     Netherlands                          269.5       22%      50%
# 12       12           Italy                          247.9       39%      36%
# 13       13           Spain                          205.8       26%      49%
# 14       14          Sweden                          199.5       10%      72%
# 15       15          Norway                          139.0        9%      71%
# 16       16         Denmark                          137.9        7%      56%
# 17       17     Switzerland                          137.8       27%      52%
# 18       18          Mexico                          137.0       15%      79%
# 19       19           India                          130.7        7%      78%
# 20       20       Argentina                          130.0        8%      31%
# 21             Global total                         17,270       n/a      n/a
#
#                      5                6
# 0   Performance Rights  Synchronization
# 1                   7%               3%
# 2                   5%               1%
# 3                  20%               1%
# 4                  18%               2%
# 5                  27%               3%
# 6                   4%               0%
# 7                  14%               1%
# 8                  11%               2%
# 9                  34%               0%
# 10                  7%               0%
# 11                 27%               0%
# 12                 22%               3%
# 13                 24%               2%
# 14                 17%               1%
# 15                 19%               1%
# 16                 36%               1%
# 17                 21%               0%
# 18                  4%               1%
# 19                  9%               6%
# 20                 60%               1%
# 21                 n/a              n/a

# %%
pip install df2gspread
# Out:
# Collecting df2gspread
#   Downloading https://files.pythonhosted.org/packages/56/c3/fc3801749129df5632deeb7b9b9ef758a0ea6a4498c207a9eb4ac36deffb/df2gspread-1.0.4.tar.gz
# Collecting argparse>=1.3.0 (from df2gspread)
#   Downloading https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Collecting google-api-python-client==1.6.7 (from df2gspread)
#   Downloading https://files.pythonhosted.org/packages/eb/6c/8c1781a251beb3bc1670d6d1934da51620a049380ea7a6a821099f884b62/google_api_python_client-1.6.7-py2.py3-none-any.whl (56kB)
# Requirement already satisfied: gspread>=2.1.1 in c:\users\manoj\anaconda3\lib\site-packages (from df2gspread) (3.6.0)
# Requirement already satisfied: oauth2client<5.0.0dev,>=1.5.0 in c:\users\manoj\anaconda3\lib\site-packages (from df2gspread) (4.1.3)
# Requirement already satisfied: pandas in c:\users\manoj\anaconda3\lib\site-packages (from df2gspread) (0.25.3)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\manoj\anaconda3\lib\site-packages (from google-api-python-client==1.6.7->df2gspread) (0.18.1)
# Requirement already satisfied: six<2dev,>=1.6.1 in c:\users\manoj\anaconda3\lib\site-packages (from google-api-python-client==1.6.7->df2gspread) (1.12.0)
# Collecting uritemplate<4dev,>=3.0.0 (from google-api-python-client==1.6.7->df2gspread)
#   Downloading https://files.pythonhosted.org/packages/bf/0c/60d82c077998feb631608dca3cc1fe19ac074e772bf0c24cf409b977b815/uritemplate-3.0.1-py2.py3-none-any.whl
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\manoj\anaconda3\lib\site-packages (from gspread>=2.1.1->df2gspread) (1.15.0)
# Requirement already satisfied: requests>=2.2.1 in c:\users\manoj\anaconda3\lib\site-packages (from gspread>=2.1.1->df2gspread) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\manoj\anaconda3\lib\site-packages (from gspread>=2.1.1->df2gspread) (0.4.1)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\manoj\anaconda3\lib\site-packages (from oauth2client<5.0.0dev,>=1.5.0->df2gspread) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\manoj\anaconda3\lib\site-packages (from oauth2client<5.0.0dev,>=1.5.0->df2gspread) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\manoj\anaconda3\lib\site-packages (from oauth2client<5.0.0dev,>=1.5.0->df2gspread) (4.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\manoj\anaconda3\lib\site-packages (from pandas->df2gspread) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\manoj\anaconda3\lib\site-packages (from pandas->df2gspread) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\manoj\anaconda3\lib\site-packages (from pandas->df2gspread) (1.16.5)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\manoj\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=2.1.1->df2gspread) (41.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\manoj\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=2.1.1->df2gspread) (4.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread>=2.1.1->df2gspread) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread>=2.1.1->df2gspread) (2019.9.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread>=2.1.1->df2gspread) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\manoj\anaconda3\lib\site-packages (from requests>=2.2.1->gspread>=2.1.1->df2gspread) (2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\manoj\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread>=2.1.1->df2gspread) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\manoj\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=2.1.1->df2gspread) (3.1.0)
# Building wheels for collected packages: df2gspread
#   Building wheel for df2gspread (setup.py): started
#   Building wheel for df2gspread (setup.py): finished with status 'done'
#   Created wheel for df2gspread: filename=df2gspread-1.0.4-cp37-none-any.whl size=11957 sha256=0ed787b9c67798ffce214b1359b903b59fbf7c5a501dbac1e01cf6543affdc52
#   Stored in directory: C:\Users\Manoj\AppData\Local\pip\Cache\wheels\19\d2\15\07b0a45a18edadbf0bb3a5655e997925e2b9cbf08b4a95342e
# Successfully built df2gspread
# Installing collected packages: argparse, uritemplate, google-api-python-client, df2gspread
# Successfully installed argparse-1.4.0 df2gspread-1.0.4 google-api-python-client-1.6.7 uritemplate-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from df2gspread import df2gspread as d2g
wks_name = 'Sheet1'
cell_of_start_df = 'A1'
d2g.upload(df,
           spreadsheet_key,
           wks_name,
           credentials=creds,
           col_names=False,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=False)
print ('The sheet is updated successfully')
# Out:
# The sheet is updated successfully
