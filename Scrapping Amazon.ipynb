# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import requests

# %%
html = urlopen('https://www.amazon.com/Lacoste-Carnaby-Sneaker-White-Medium/dp/B07T5Q2VLG?s=shopbop&ref_=sb_ts')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-2fd346039891> in <module>
# ----> 1 html = urlopen('https://www.amazon.com/Lacoste-Carnaby-Sneaker-White-Medium/dp/B07T5Q2VLG?s=shopbop&ref_=sb_ts')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
# ...

# %%
header = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36','Referer':'https://www.amazon.com/stores/page/0B6B05F4-EE4D-4696-A789-BB7152AB8DCE?ingress=0&visitId=9365015c-39f1-4f05-8ec9-61dfafb3a84a&channel=SB-gway&liveVideoDataUrl=https%3A%2F%2Famazonlive-portal.amazon.com%2Fv2&ref_=sb_w_i_ctcd_snkrs&productGridPageIndex=4'}

# %%
url = 'https://www.amazon.com/Lacoste-Carnaby-Sneaker-White-Medium/dp/B07T5Q2VLG?s=shopbop&ref_=sb_ts'

# %%
html = requests.get(url,headers=header)
html
# Out:
# <Response [200]>

# %%
bsobj = soup(html.content,'lxml')
bsobj
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script><!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/><link crossorigin="" href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/><link crossorigin="" href="https://images-na.ssl-images-amazon.com" rel="preconnect"/><link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/><link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/><link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/><link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/><script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %% [markdown]
# ### 1. Brand Name

# %%
bsobj.findAll('div',{'class':'a-section a-spacing-none'})[0].a.text
# Out:
# 'Lacoste'

# %% [markdown]
# ### 2. Product Name

# %%
bsobj.h1.text.strip()
# Out:
# "Lacoste Men's Carnaby Evo 120 7 Us SMA Sneaker"

# %% [markdown]
# ### 3. Ratings

# %%
bsobj.findAll('i',{'class':'a-icon a-icon-star a-star-3'})[0].text
# Out:
# '3.0 out of 5 stars'

# %% [markdown]
# ### 4. PRICE

# %%
bsobj.findAll('table',{'class':'a-lineitem'})[0].tr.span.text
# Out:
# '$49.30 - $114.95'

# %% [markdown]
# ### 5. Size

# %%
bsobj.findAll('span',{'class':'a-dropdown-container'})[0].findAll('option')[1:]
# Out:
# [<option class="dropdownUnavailable" data-a-css-class="dropdownUnavailable" data-a-html-content="5" data-a-id="size_name_0" id="native_size_name_0" value="0,B07SPH7MQD">
#                      5
#                  </option>,
#  <option class="dropdownUnavailable" data-a-css-class="dropdownUnavailable" data-a-html-content="5.5" data-a-id="size_name_1" id="native_size_name_1" value="1,B07SPH65T3">
#                      5.5
#                  </option>,
#  <option class="dropdownUnavailable" data-a-css-class="dropdownUnavailable" data-a-html-content="6.5" data-a-id="size_name_2" id="native_size_name_2" value="2,B07SL6SB71">
#                      6.5
#                  </option>,
#  <option class="dropdownAvailable" data-a-css-class="dropdownAvailable" data-a-html-content="7" data-a-id="size_name_3" id="native_size_name_3" value="3,B07T3HTF9C">
#                      7
#                  </option>,
# ...

# %%
for a in bsobj.findAll('span',{'class':'a-dropdown-container'})[0].findAll('option')[1:]:
    print(a.text.strip())
# Out:
# 5
# 5.5
# 6.5
# 7
# 7.5
# 8
# 8.5
# 9
# 9.5
# 10
# 10.5
# 11
# 11.5
# 12
# 13
# women 2
# womens 12

# %% [markdown]
# ### 6. Color

# %%
colors =[]
for a in range(0,6):
    name = 'color_name_' + str(a)
    colors.append(name)
colors
# Out:
# ['color_name_0',
#  'color_name_1',
#  'color_name_2',
#  'color_name_3',
#  'color_name_4',
#  'color_name_5']

# %%
for color in bsobj.findAll('li',{'id':colors}):
    print(color.img['alt'])
# Out:
# Black/White
# White/Green
# White/Navy
# White/Red
# White Wht Nvy 042
# White Wht Grn 082
